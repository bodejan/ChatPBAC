# %%
import pandas as pd

df_1 = pd.read_csv('dataset_1.csv', index_col='Visit ID')
df_1
# Out:
#            Visit Date Patient ID                     Diagnosis Category  \
# Visit ID
# VQC513203  2017-01-01  PZM508653                           Chronic Pain
# VVC435406  2017-01-01  PSN036517                   Endocrine/ Metabolic
# VKT437745  2017-01-01  PPD253419                             Pediatrics
# VJG208744  2017-01-01  PBN488954  Central Nervous System/ Neuromuscular
# VAF235393  2017-01-01  PJG173047                                 Cancer
# ...               ...        ...                                    ...
# VTL998110  2018-12-30  PND058072                                 Mental
# VBT985120  2018-12-30  PIT750921            Orthopedic/ Musculoskeletal
# VLH032189  2018-12-30  PPC895292                                 Cancer
# VKA771318  2018-12-30  PDB455996                   Endocrine/ Metabolic
# VCG668375  2018-12-30  PFN080564                     Ears, Nose, Throat
#
#            Diagnosis Sub Category  \
# Visit ID
# VQC513203  Vertebral Disc Problem
# VVC435406      Hormone Deficiency
# VKT437745          Delayed Speech
# VJG208744                     NaN
# VAF235393           Breast Cancer
# ...                           ...
# VTL998110              Depression
# VBT985120        Shoulder Problem
# VLH032189            Liver Cancer
# VKA771318        Thyroid Problems
# VCG668375            Otitis Media
#
#                                       Treatment Category  \
# Visit ID
# VQC513203                    Pharmacy/Prescription Drugs
# VVC435406                    Pharmacy/Prescription Drugs
# VKT437745           Rehabilitation Services - Outpatient
# VJG208744                    Pharmacy/Prescription Drugs
# VAF235393                               Cancer Treatment
# ...                                                  ...
# VTL998110  Electrical/ Thermal/ Radiofreq. Interventions
# VBT985120      Diagnostic Imaging, Screening and Testing
# VLH032189                              Special Procedure
# VKA771318            Acute Medical Services - Outpatient
# VCG668375            Acute Medical Services - Outpatient
#
#                       Treatment Sub Category  New Patient  \
# Visit ID
# VQC513203               Non-FDA Approved Use         True
# VVC435406                           Hormones         True
# VKT437745                     Speech Therapy         True
# VJG208744               Non-FDA Approved Use         True
# VAF235393                            Surgery         True
# ...                                      ...          ...
# VTL998110  Transcranial Magnetic Stimulation        False
# VBT985120                                MRI        False
# VLH032189                                NaN        False
# VKA771318                     Emergency Room        False
# VCG668375                     Emergency Room        False
#
#             Consulting Physician          Patient Name Patient Gender  \
# Visit ID
# VQC513203      Dr. Jerry Daniels       Michelle Fisher         Female
# VVC435406      Dr. Michelle Lamb          Brooke Davis         Female
# VKT437745      Dr. Michelle Lamb         Andrew Graves           Male
# VJG208744       Dr. James Barber        Cody Carpenter           Male
# VAF235393       Dr. James Barber     Christopher White         Female
# ...                          ...                   ...            ...
# VTL998110  Dr. Alexandria Gaines             Jean Rios           Male
# VBT985120        Dr. Shelly Hunt           Jesse Terry           Male
# VLH032189        Dr. Eddie Young          Hailey Terry           Male
# VKA771318      Dr. Michelle Lamb  Christopher Williams         Female
# VCG668375      Dr. Michelle Lamb             Beth Ross           Male
#
#            Patient Age Patient Age Range Patient Blood Type  \
# Visit ID
# VQC513203           43             41-50                 O-
# VVC435406           36             31-40                 O+
# VKT437745            5              0-10                 O+
# VJG208744           52             51-64                AB+
# VAF235393           36             31-40                 A+
# ...                ...               ...                ...
# VTL998110           51             51-64                 A-
# VBT985120           52             51-64                 B+
# VLH032189           62             51-64                 B-
# VKA771318           54             51-64                AB+
# VCG668375           46             41-50                 O-
#
#           Patient Insurance Number  Patient Phone  \
# Visit ID
# VQC513203               G264037622    15786233257
# VVC435406               Y133547589    16238255302
# VKT437745               F115599209    17550508440
# VJG208744               W720918648    15210588122
# VAF235393               Q198981012    16561784363
# ...                            ...            ...
# VTL998110                  Private    16805112343
# VBT985120               U505643033    17924524385
# VLH032189               Q100759966    15775878159
# VKA771318                  Private    16951975501
# VCG668375               J503309960    17141962660
#
#                                              Patient Address  \
# Visit ID
# VQC513203            Pärtzeltweg 2\n22301 Neunburg vorm Wald
# VVC435406              Kira-Gorlitz-Allee 8\n67100 Rosenheim
# VKT437745                        Thiesstr. 3/5\n68745 Bremen
# VJG208744                    Schmidtkeallee 53\n54913 Siegen
# VAF235393               Ida-Fliegner-Ring 7/6\n53118 Wolgast
# ...                                                      ...
# VTL998110  Wolfram-auch Schlauchin-Ring 3/3\n94816 Neuruppin
# VBT985120                       Miesplatz 31\n22468 Bayreuth
# VLH032189                     Sölzerring 05\n21768 Altötting
# VKA771318                  Fiebigplatz 5\n26886 Fürstenwalde
# VCG668375                       Hofmannweg 06\n38230 Hagenow
#
#                             Patient Occupation  \
# Visit ID
# VQC513203                   Surveyor, quantity
# VVC435406                                 Copy
# VKT437745            Claims inspector/assessor
# VJG208744                      Tourism officer
# VAF235393                Engineering geologist
# ...                                        ...
# VTL998110    Research officer, political party
# VBT985120  Social research officer, government
# VLH032189                  Engineer, petroleum
# VKA771318                  Chemist, analytical
# VCG668375               Pension scheme manager
#
#                    Patient Emergency Contact
# Visit ID
# VQC513203     Jennifer Bailey, 015680180768.
# VVC435406      Dennis Carlson, 015182104709.
# VKT437745     Veronica Harris, 015034485673.
# VJG208744     Michelle Graham, 017438105819.
# VAF235393         Peter Stout, 015017527431.
# ...                                      ...
# VTL998110       Emily Garrett, 016593887796.
# VBT985120  Jeanette Rodriguez, 017833888272.
# VLH032189        Linda Flores, 016973980632.
# VKA771318       James Farrell, 015303912796.
# VCG668375      Pamela English, 017505981536.
#
# [11689 rows x 18 columns]

# %%
df_2 = pd.read_csv('dataset_2.csv', index_col='Visit ID')
df_2
# Out:
#                                                  Description
# Visit ID
# VVC435406  The patient presented with symptoms of fatigue...
# VKT437745  The patient presented with delayed speech deve...
# VJG208744  The patient presented with symptoms of muscle ...
# VAF235393  The patient presented with a diagnosis of brea...
# VQC513203  The patient presented with chronic lower back ...
# ...                                                      ...
# VYV246792  Today I met with a young patient who was broug...
# VBO082144  The patient presented with symptoms of persist...
# VKA771318  The patient presented with symptoms of severe ...
# VQZ422704  Today I saw a patient with a chromosomal anoma...
# VCG668375  I saw a patient in the emergency room today wi...
#
# [11689 rows x 1 columns]

# %%
df_3 = df_1.merge(df_2, left_index=True, right_index=True)
df_3
# Out:
#            Visit Date Patient ID                     Diagnosis Category  \
# Visit ID
# VQC513203  2017-01-01  PZM508653                           Chronic Pain
# VVC435406  2017-01-01  PSN036517                   Endocrine/ Metabolic
# VKT437745  2017-01-01  PPD253419                             Pediatrics
# VJG208744  2017-01-01  PBN488954  Central Nervous System/ Neuromuscular
# VAF235393  2017-01-01  PJG173047                                 Cancer
# ...               ...        ...                                    ...
# VTL998110  2018-12-30  PND058072                                 Mental
# VBT985120  2018-12-30  PIT750921            Orthopedic/ Musculoskeletal
# VLH032189  2018-12-30  PPC895292                                 Cancer
# VKA771318  2018-12-30  PDB455996                   Endocrine/ Metabolic
# VCG668375  2018-12-30  PFN080564                     Ears, Nose, Throat
#
#            Diagnosis Sub Category  \
# Visit ID
# VQC513203  Vertebral Disc Problem
# VVC435406      Hormone Deficiency
# VKT437745          Delayed Speech
# VJG208744                     NaN
# VAF235393           Breast Cancer
# ...                           ...
# VTL998110              Depression
# VBT985120        Shoulder Problem
# VLH032189            Liver Cancer
# VKA771318        Thyroid Problems
# VCG668375            Otitis Media
#
#                                       Treatment Category  \
# Visit ID
# VQC513203                    Pharmacy/Prescription Drugs
# VVC435406                    Pharmacy/Prescription Drugs
# VKT437745           Rehabilitation Services - Outpatient
# VJG208744                    Pharmacy/Prescription Drugs
# VAF235393                               Cancer Treatment
# ...                                                  ...
# VTL998110  Electrical/ Thermal/ Radiofreq. Interventions
# VBT985120      Diagnostic Imaging, Screening and Testing
# VLH032189                              Special Procedure
# VKA771318            Acute Medical Services - Outpatient
# VCG668375            Acute Medical Services - Outpatient
#
#                       Treatment Sub Category  New Patient  \
# Visit ID
# VQC513203               Non-FDA Approved Use         True
# VVC435406                           Hormones         True
# VKT437745                     Speech Therapy         True
# VJG208744               Non-FDA Approved Use         True
# VAF235393                            Surgery         True
# ...                                      ...          ...
# VTL998110  Transcranial Magnetic Stimulation        False
# VBT985120                                MRI        False
# VLH032189                                NaN        False
# VKA771318                     Emergency Room        False
# VCG668375                     Emergency Room        False
#
#             Consulting Physician          Patient Name Patient Gender  \
# Visit ID
# VQC513203      Dr. Jerry Daniels       Michelle Fisher         Female
# VVC435406      Dr. Michelle Lamb          Brooke Davis         Female
# VKT437745      Dr. Michelle Lamb         Andrew Graves           Male
# VJG208744       Dr. James Barber        Cody Carpenter           Male
# VAF235393       Dr. James Barber     Christopher White         Female
# ...                          ...                   ...            ...
# VTL998110  Dr. Alexandria Gaines             Jean Rios           Male
# VBT985120        Dr. Shelly Hunt           Jesse Terry           Male
# VLH032189        Dr. Eddie Young          Hailey Terry           Male
# VKA771318      Dr. Michelle Lamb  Christopher Williams         Female
# VCG668375      Dr. Michelle Lamb             Beth Ross           Male
#
#            Patient Age Patient Age Range Patient Blood Type  \
# Visit ID
# VQC513203           43             41-50                 O-
# VVC435406           36             31-40                 O+
# VKT437745            5              0-10                 O+
# VJG208744           52             51-64                AB+
# VAF235393           36             31-40                 A+
# ...                ...               ...                ...
# VTL998110           51             51-64                 A-
# VBT985120           52             51-64                 B+
# VLH032189           62             51-64                 B-
# VKA771318           54             51-64                AB+
# VCG668375           46             41-50                 O-
#
#           Patient Insurance Number  Patient Phone  \
# Visit ID
# VQC513203               G264037622    15786233257
# VVC435406               Y133547589    16238255302
# VKT437745               F115599209    17550508440
# VJG208744               W720918648    15210588122
# VAF235393               Q198981012    16561784363
# ...                            ...            ...
# VTL998110                  Private    16805112343
# VBT985120               U505643033    17924524385
# VLH032189               Q100759966    15775878159
# VKA771318                  Private    16951975501
# VCG668375               J503309960    17141962660
#
#                                              Patient Address  \
# Visit ID
# VQC513203            Pärtzeltweg 2\n22301 Neunburg vorm Wald
# VVC435406              Kira-Gorlitz-Allee 8\n67100 Rosenheim
# VKT437745                        Thiesstr. 3/5\n68745 Bremen
# VJG208744                    Schmidtkeallee 53\n54913 Siegen
# VAF235393               Ida-Fliegner-Ring 7/6\n53118 Wolgast
# ...                                                      ...
# VTL998110  Wolfram-auch Schlauchin-Ring 3/3\n94816 Neuruppin
# VBT985120                       Miesplatz 31\n22468 Bayreuth
# VLH032189                     Sölzerring 05\n21768 Altötting
# VKA771318                  Fiebigplatz 5\n26886 Fürstenwalde
# VCG668375                       Hofmannweg 06\n38230 Hagenow
#
#                             Patient Occupation  \
# Visit ID
# VQC513203                   Surveyor, quantity
# VVC435406                                 Copy
# VKT437745            Claims inspector/assessor
# VJG208744                      Tourism officer
# VAF235393                Engineering geologist
# ...                                        ...
# VTL998110    Research officer, political party
# VBT985120  Social research officer, government
# VLH032189                  Engineer, petroleum
# VKA771318                  Chemist, analytical
# VCG668375               Pension scheme manager
#
#                    Patient Emergency Contact  \
# Visit ID
# VQC513203     Jennifer Bailey, 015680180768.
# VVC435406      Dennis Carlson, 015182104709.
# VKT437745     Veronica Harris, 015034485673.
# VJG208744     Michelle Graham, 017438105819.
# VAF235393         Peter Stout, 015017527431.
# ...                                      ...
# VTL998110       Emily Garrett, 016593887796.
# VBT985120  Jeanette Rodriguez, 017833888272.
# VLH032189        Linda Flores, 016973980632.
# VKA771318       James Farrell, 015303912796.
# VCG668375      Pamela English, 017505981536.
#
#                                                  Description
# Visit ID
# VQC513203  The patient presented with chronic lower back ...
# VVC435406  The patient presented with symptoms of fatigue...
# VKT437745  The patient presented with delayed speech deve...
# VJG208744  The patient presented with symptoms of muscle ...
# VAF235393  The patient presented with a diagnosis of brea...
# ...                                                      ...
# VTL998110  Today, I met with a patient who was diagnosed ...
# VBT985120  The patient presented with persistent shoulder...
# VLH032189  The patient was diagnosed with liver cancer af...
# VKA771318  The patient presented with symptoms of severe ...
# VCG668375  I saw a patient in the emergency room today wi...
#
# [11689 rows x 19 columns]

# %%
re_order = [
    'Description', 'Visit Date', 'Patient ID', 'Diagnosis Category', 
    'Diagnosis Sub Category', 'Treatment Category', 'Treatment Sub Category', 
    'New Patient', 'Consulting Physician', 'Patient Name', 'Patient Gender', 'Patient Age',
    'Patient Age Range', 'Patient Blood Type', 'Patient Insurance Number', 
    'Patient Phone', 'Patient Address', 'Patient Occupation', 'Patient Emergency Contact'
]
df_3 = df_3[re_order]
df_3
# Out:
#                                                  Description  Visit Date  \
# Visit ID
# VQC513203  The patient presented with chronic lower back ...  2017-01-01
# VVC435406  The patient presented with symptoms of fatigue...  2017-01-01
# VKT437745  The patient presented with delayed speech deve...  2017-01-01
# VJG208744  The patient presented with symptoms of muscle ...  2017-01-01
# VAF235393  The patient presented with a diagnosis of brea...  2017-01-01
# ...                                                      ...         ...
# VTL998110  Today, I met with a patient who was diagnosed ...  2018-12-30
# VBT985120  The patient presented with persistent shoulder...  2018-12-30
# VLH032189  The patient was diagnosed with liver cancer af...  2018-12-30
# VKA771318  The patient presented with symptoms of severe ...  2018-12-30
# VCG668375  I saw a patient in the emergency room today wi...  2018-12-30
#
#           Patient ID                     Diagnosis Category  \
# Visit ID
# VQC513203  PZM508653                           Chronic Pain
# VVC435406  PSN036517                   Endocrine/ Metabolic
# VKT437745  PPD253419                             Pediatrics
# VJG208744  PBN488954  Central Nervous System/ Neuromuscular
# VAF235393  PJG173047                                 Cancer
# ...              ...                                    ...
# VTL998110  PND058072                                 Mental
# VBT985120  PIT750921            Orthopedic/ Musculoskeletal
# VLH032189  PPC895292                                 Cancer
# VKA771318  PDB455996                   Endocrine/ Metabolic
# VCG668375  PFN080564                     Ears, Nose, Throat
#
#            Diagnosis Sub Category  \
# Visit ID
# VQC513203  Vertebral Disc Problem
# VVC435406      Hormone Deficiency
# VKT437745          Delayed Speech
# VJG208744                     NaN
# VAF235393           Breast Cancer
# ...                           ...
# VTL998110              Depression
# VBT985120        Shoulder Problem
# VLH032189            Liver Cancer
# VKA771318        Thyroid Problems
# VCG668375            Otitis Media
#
#                                       Treatment Category  \
# Visit ID
# VQC513203                    Pharmacy/Prescription Drugs
# VVC435406                    Pharmacy/Prescription Drugs
# VKT437745           Rehabilitation Services - Outpatient
# VJG208744                    Pharmacy/Prescription Drugs
# VAF235393                               Cancer Treatment
# ...                                                  ...
# VTL998110  Electrical/ Thermal/ Radiofreq. Interventions
# VBT985120      Diagnostic Imaging, Screening and Testing
# VLH032189                              Special Procedure
# VKA771318            Acute Medical Services - Outpatient
# VCG668375            Acute Medical Services - Outpatient
#
#                       Treatment Sub Category  New Patient  \
# Visit ID
# VQC513203               Non-FDA Approved Use         True
# VVC435406                           Hormones         True
# VKT437745                     Speech Therapy         True
# VJG208744               Non-FDA Approved Use         True
# VAF235393                            Surgery         True
# ...                                      ...          ...
# VTL998110  Transcranial Magnetic Stimulation        False
# VBT985120                                MRI        False
# VLH032189                                NaN        False
# VKA771318                     Emergency Room        False
# VCG668375                     Emergency Room        False
#
#             Consulting Physician          Patient Name Patient Gender  \
# Visit ID
# VQC513203      Dr. Jerry Daniels       Michelle Fisher         Female
# VVC435406      Dr. Michelle Lamb          Brooke Davis         Female
# VKT437745      Dr. Michelle Lamb         Andrew Graves           Male
# VJG208744       Dr. James Barber        Cody Carpenter           Male
# VAF235393       Dr. James Barber     Christopher White         Female
# ...                          ...                   ...            ...
# VTL998110  Dr. Alexandria Gaines             Jean Rios           Male
# VBT985120        Dr. Shelly Hunt           Jesse Terry           Male
# VLH032189        Dr. Eddie Young          Hailey Terry           Male
# VKA771318      Dr. Michelle Lamb  Christopher Williams         Female
# VCG668375      Dr. Michelle Lamb             Beth Ross           Male
#
#            Patient Age Patient Age Range Patient Blood Type  \
# Visit ID
# VQC513203           43             41-50                 O-
# VVC435406           36             31-40                 O+
# VKT437745            5              0-10                 O+
# VJG208744           52             51-64                AB+
# VAF235393           36             31-40                 A+
# ...                ...               ...                ...
# VTL998110           51             51-64                 A-
# VBT985120           52             51-64                 B+
# VLH032189           62             51-64                 B-
# VKA771318           54             51-64                AB+
# VCG668375           46             41-50                 O-
#
#           Patient Insurance Number  Patient Phone  \
# Visit ID
# VQC513203               G264037622    15786233257
# VVC435406               Y133547589    16238255302
# VKT437745               F115599209    17550508440
# VJG208744               W720918648    15210588122
# VAF235393               Q198981012    16561784363
# ...                            ...            ...
# VTL998110                  Private    16805112343
# VBT985120               U505643033    17924524385
# VLH032189               Q100759966    15775878159
# VKA771318                  Private    16951975501
# VCG668375               J503309960    17141962660
#
#                                              Patient Address  \
# Visit ID
# VQC513203            Pärtzeltweg 2\n22301 Neunburg vorm Wald
# VVC435406              Kira-Gorlitz-Allee 8\n67100 Rosenheim
# VKT437745                        Thiesstr. 3/5\n68745 Bremen
# VJG208744                    Schmidtkeallee 53\n54913 Siegen
# VAF235393               Ida-Fliegner-Ring 7/6\n53118 Wolgast
# ...                                                      ...
# VTL998110  Wolfram-auch Schlauchin-Ring 3/3\n94816 Neuruppin
# VBT985120                       Miesplatz 31\n22468 Bayreuth
# VLH032189                     Sölzerring 05\n21768 Altötting
# VKA771318                  Fiebigplatz 5\n26886 Fürstenwalde
# VCG668375                       Hofmannweg 06\n38230 Hagenow
#
#                             Patient Occupation  \
# Visit ID
# VQC513203                   Surveyor, quantity
# VVC435406                                 Copy
# VKT437745            Claims inspector/assessor
# VJG208744                      Tourism officer
# VAF235393                Engineering geologist
# ...                                        ...
# VTL998110    Research officer, political party
# VBT985120  Social research officer, government
# VLH032189                  Engineer, petroleum
# VKA771318                  Chemist, analytical
# VCG668375               Pension scheme manager
#
#                    Patient Emergency Contact
# Visit ID
# VQC513203     Jennifer Bailey, 015680180768.
# VVC435406      Dennis Carlson, 015182104709.
# VKT437745     Veronica Harris, 015034485673.
# VJG208744     Michelle Graham, 017438105819.
# VAF235393         Peter Stout, 015017527431.
# ...                                      ...
# VTL998110       Emily Garrett, 016593887796.
# VBT985120  Jeanette Rodriguez, 017833888272.
# VLH032189        Linda Flores, 016973980632.
# VKA771318       James Farrell, 015303912796.
# VCG668375      Pamela English, 017505981536.
#
# [11689 rows x 19 columns]

# %%
df_3.to_csv('dataset_3.csv')

# %%
df_3['Patient Age'].value_counts()
# Out:
# Patient Age
# 59    379
# 60    372
# 61    369
# 54    363
# 52    358
#      ...
# 94      6
# 69      4
# 98      3
# 87      2
# 82      1
# Name: count, Length: 83, dtype: int64

# %% [markdown]
# ## Intended Purposes
#
# ### Clinical Care:
# - **Description**: Facilitates ongoing patient care by providing healthcare providers with comprehensive access to patient histories, diagnoses, treatments, and contact information. This purpose supports informed clinical decisions and personalized care plans.
# - **Matching Data**: Patient ID, Description, Visit Date, Diagnosis Category, Diagnosis Sub Category, Treatment Category, Treatment Sub Category, Patient Name, Patient Gender, Patient Age Range, Patient Blood Type, Patient Emergency Contact.
#
# ### Research:
# - **Description**: Supports medical research by allowing access to anonymized patient data, focusing on diagnosis and treatment outcomes. Researchers can study patterns, effectiveness, and potential improvements in healthcare delivery and treatments.
# - **Matching Data**: Diagnosis Category, Diagnosis Sub Category, Treatment Category, Treatment Sub Category, Patient Age Range, Patient Gender, New Patient (for population dynamics).
#
# ### Billing and Insurance Claims Processing:
# - **Description**: Enables the processing of billing and insurance claims through access to patient insurance information, treatment categories, and patient identifiers. This purpose assists in verifying coverage and submitting claims to insurance providers.
# - **Matching Data**: Patient Name, Patient Address, Treatment Category, Treatment Sub Category, Patient Insurance Number.
#
# ### Patient Support Services:
# - **Description**: Facilitates the provision of support services to patients, including appointment scheduling, follow-up arrangements, and emergency contact communication. Ensures patients receive timely care and information.
# - **Matching Data**: Patient Name, Patient Phone, Patient Address, Patient Emergency Contact, New Patient, Consulting Physician.
#
# ### Public Health Monitoring and Response:
# - **Description**: Allows for the monitoring of public health trends and the management of health crises by analyzing aggregated data on diagnoses, treatments, and patient demographics. Supports public health initiatives and emergency response planning.
# - **Matching Data**: Diagnosis Category, Diagnosis Sub Category, Treatment Category, Treatment Sub Category, Patient Age Range, Patient Gender, Visit Date.
#
# ### Clinical Trial Recruitment:
# - **Description**: Supports the identification and recruitment of potential clinical trial participants by matching patient diagnoses and treatments with trial eligibility criteria. Facilitates advancements in medical research and treatment development.
# - **Matching Data**: Patient ID, Diagnosis Category, Diagnosis Sub Category, Patient Age Range, Patient Gender, New Patient.
#
# ### Product Development:
# - **Description**: Informs the development of medical products and services by analyzing treatment outcomes, patient demographics, and health conditions. Drives innovation in healthcare solutions tailored to patient needs.
# - **Matching Data**: Diagnosis Category, Diagnosis Sub Category, Treatment Category, Treatment Sub Category, Patient Age Range, Patient Gender, New Patient.
#
# ### Marketing:
# - **Description**: Tailors health-related marketing initiatives to patient demographics and conditions, promoting relevant healthcare services, products, and wellness programs. Aims to enhance patient engagement and healthcare outcomes.
# - **Matching Data**: Patient Age Range, Patient Gender, Diagnosis Category, Treatment Category, New Patient (to understand market segments and needs).

# %%
purposes = ['Care', 'Research', 'Insurance', 'Support', 'Public', 'Trial', 'Product', 'Marketing']
