# %%
import pandas as pd

df_1 = pd.read_csv('dataset_1.csv', index_col='Visit ID')
df_1
# Out:
#            Visit Date Patient ID                     Diagnosis Category  \
# Visit ID
# VQC513203  2017-01-01  PZM508653                           Chronic Pain
# VVC435406  2017-01-01  PSN036517                   Endocrine/ Metabolic
# VKT437745  2017-01-01  PPD253419                             Pediatrics
# VJG208744  2017-01-01  PBN488954  Central Nervous System/ Neuromuscular
# VAF235393  2017-01-01  PJG173047                                 Cancer
# ...               ...        ...                                    ...
# VYV246792  2018-12-30  PBM172577                             Pediatrics
# VBO082144  2018-12-30  PVI648420                                 Mental
# VKA771318  2018-12-30  PDB455996                   Endocrine/ Metabolic
# VQZ422704  2018-12-30  PFS771409                                Genetic
# VCG668375  2018-12-30  PFN080564                     Ears, Nose, Throat
#
#            Diagnosis Sub Category  \
# Visit ID
# VQC513203  Vertebral Disc Problem
# VVC435406      Hormone Deficiency
# VKT437745          Delayed Speech
# VJG208744                     NaN
# VAF235393           Breast Cancer
# ...                           ...
# VYV246792          Delayed Speech
# VBO082144              Depression
# VKA771318        Thyroid Problems
# VQZ422704   Chromosomal Anomalies
# VCG668375            Otitis Media
#
#                                       Treatment Category  \
# Visit ID
# VQC513203                    Pharmacy/Prescription Drugs
# VVC435406                    Pharmacy/Prescription Drugs
# VKT437745           Rehabilitation Services - Outpatient
# VJG208744                    Pharmacy/Prescription Drugs
# VAF235393                               Cancer Treatment
# ...                                                  ...
# VYV246792           Rehabilitation Services - Outpatient
# VBO082144  Electrical/ Thermal/ Radiofreq. Interventions
# VKA771318            Acute Medical Services - Outpatient
# VQZ422704                    Pharmacy/Prescription Drugs
# VCG668375            Acute Medical Services - Outpatient
#
#           Treatment Sub Category  New Patient   Consulting Physician  \
# Visit ID
# VQC513203   Non-FDA Approved Use         True      Dr. Jerry Daniels
# VVC435406               Hormones         True      Dr. Michelle Lamb
# VKT437745         Speech Therapy         True      Dr. Michelle Lamb
# VJG208744   Non-FDA Approved Use         True       Dr. James Barber
# VAF235393                Surgery         True       Dr. James Barber
# ...                          ...          ...                    ...
# VYV246792         Speech Therapy        False       Dr. James Barber
# VBO082144                    NaN        False  Dr. Alexandria Gaines
# VKA771318         Emergency Room        False      Dr. Michelle Lamb
# VQZ422704               Hormones        False       Dr. James Barber
# VCG668375         Emergency Room        False      Dr. Michelle Lamb
#
#                    Patient Name Patient Gender Patient Age Range  \
# Visit ID
# VQC513203       Michelle Fisher         Female             41-50
# VVC435406          Brooke Davis         Female             31-40
# VKT437745         Andrew Graves           Male              0-10
# VJG208744        Cody Carpenter           Male             51-64
# VAF235393     Christopher White         Female             31-40
# ...                         ...            ...               ...
# VYV246792         Kenneth Smith           Male              0-10
# VBO082144         Kristin Jones         Female             51-64
# VKA771318  Christopher Williams         Female             51-64
# VQZ422704       Pamela Mcgee MD         Female              0-10
# VCG668375             Beth Ross           Male             41-50
#
#           Patient Blood Type Patient Insurance Number  Patient Phone  \
# Visit ID
# VQC513203                 O-               G264037622    15786233257
# VVC435406                 O+               Y133547589    16238255302
# VKT437745                 O+               F115599209    17550508440
# VJG208744                AB+               W720918648    15210588122
# VAF235393                 A+               Q198981012    16561784363
# ...                      ...                      ...            ...
# VYV246792                 B+               H797815344    17316183697
# VBO082144                AB+               Z982649988    17953227317
# VKA771318                AB+                  Private    16951975501
# VQZ422704                 A+               L605331052    15918361501
# VCG668375                 O-               J503309960    17141962660
#
#                                    Patient Address  \
# Visit ID
# VQC513203  Pärtzeltweg 2\n22301 Neunburg vorm Wald
# VVC435406    Kira-Gorlitz-Allee 8\n67100 Rosenheim
# VKT437745              Thiesstr. 3/5\n68745 Bremen
# VJG208744          Schmidtkeallee 53\n54913 Siegen
# VAF235393     Ida-Fliegner-Ring 7/6\n53118 Wolgast
# ...                                            ...
# VYV246792   Steinbergstr. 5/9\n43481 Ebermannstadt
# VBO082144             Beckerplatz 0\n46198 Beeskow
# VKA771318        Fiebigplatz 5\n26886 Fürstenwalde
# VQZ422704          Mielcarekplatz 1/9\n83357 Melle
# VCG668375             Hofmannweg 06\n38230 Hagenow
#
#                          Patient Occupation       Patient Emergency Contact
# Visit ID
# VQC513203                Surveyor, quantity  Jennifer Bailey, 015680180768.
# VVC435406                              Copy   Dennis Carlson, 015182104709.
# VKT437745         Claims inspector/assessor  Veronica Harris, 015034485673.
# VJG208744                   Tourism officer  Michelle Graham, 017438105819.
# VAF235393             Engineering geologist      Peter Stout, 015017527431.
# ...                                     ...                             ...
# VYV246792                 Librarian, public  Steven Caldwell, 015315613798.
# VBO082144                     Site engineer    Scott Simpson, 016581707368.
# VKA771318               Chemist, analytical    James Farrell, 015303912796.
# VQZ422704  Scientific laboratory technician    Michael Weiss, 017716313028.
# VCG668375            Pension scheme manager   Pamela English, 017505981536.
#
# [11689 rows x 17 columns]

# %%
df_2 = pd.read_csv('dataset_2.csv', index_col='Visit ID')
df_2
# Out:
#                                                  Description
# Visit ID
# VVC435406  The patient presented with symptoms of fatigue...
# VKT437745  The patient presented with delayed speech deve...
# VJG208744  The patient presented with symptoms of muscle ...
# VAF235393  The patient presented with a diagnosis of brea...
# VQC513203  The patient presented with chronic lower back ...
# ...                                                      ...
# VYV246792  Today I met with a young patient who was broug...
# VBO082144  The patient presented with symptoms of persist...
# VKA771318  The patient presented with symptoms of severe ...
# VQZ422704  Today I saw a patient with a chromosomal anoma...
# VCG668375  I saw a patient in the emergency room today wi...
#
# [11689 rows x 1 columns]

# %%
df_3 = df_1.merge(df_2, left_index=True, right_index=True)
df_3
# Out:
#            Visit Date Patient ID                     Diagnosis Category  \
# Visit ID
# VQC513203  2017-01-01  PZM508653                           Chronic Pain
# VVC435406  2017-01-01  PSN036517                   Endocrine/ Metabolic
# VKT437745  2017-01-01  PPD253419                             Pediatrics
# VJG208744  2017-01-01  PBN488954  Central Nervous System/ Neuromuscular
# VAF235393  2017-01-01  PJG173047                                 Cancer
# ...               ...        ...                                    ...
# VYV246792  2018-12-30  PBM172577                             Pediatrics
# VBO082144  2018-12-30  PVI648420                                 Mental
# VKA771318  2018-12-30  PDB455996                   Endocrine/ Metabolic
# VQZ422704  2018-12-30  PFS771409                                Genetic
# VCG668375  2018-12-30  PFN080564                     Ears, Nose, Throat
#
#            Diagnosis Sub Category  \
# Visit ID
# VQC513203  Vertebral Disc Problem
# VVC435406      Hormone Deficiency
# VKT437745          Delayed Speech
# VJG208744                     NaN
# VAF235393           Breast Cancer
# ...                           ...
# VYV246792          Delayed Speech
# VBO082144              Depression
# VKA771318        Thyroid Problems
# VQZ422704   Chromosomal Anomalies
# VCG668375            Otitis Media
#
#                                       Treatment Category  \
# Visit ID
# VQC513203                    Pharmacy/Prescription Drugs
# VVC435406                    Pharmacy/Prescription Drugs
# VKT437745           Rehabilitation Services - Outpatient
# VJG208744                    Pharmacy/Prescription Drugs
# VAF235393                               Cancer Treatment
# ...                                                  ...
# VYV246792           Rehabilitation Services - Outpatient
# VBO082144  Electrical/ Thermal/ Radiofreq. Interventions
# VKA771318            Acute Medical Services - Outpatient
# VQZ422704                    Pharmacy/Prescription Drugs
# VCG668375            Acute Medical Services - Outpatient
#
#           Treatment Sub Category  New Patient   Consulting Physician  \
# Visit ID
# VQC513203   Non-FDA Approved Use         True      Dr. Jerry Daniels
# VVC435406               Hormones         True      Dr. Michelle Lamb
# VKT437745         Speech Therapy         True      Dr. Michelle Lamb
# VJG208744   Non-FDA Approved Use         True       Dr. James Barber
# VAF235393                Surgery         True       Dr. James Barber
# ...                          ...          ...                    ...
# VYV246792         Speech Therapy        False       Dr. James Barber
# VBO082144                    NaN        False  Dr. Alexandria Gaines
# VKA771318         Emergency Room        False      Dr. Michelle Lamb
# VQZ422704               Hormones        False       Dr. James Barber
# VCG668375         Emergency Room        False      Dr. Michelle Lamb
#
#                    Patient Name Patient Gender Patient Age Range  \
# Visit ID
# VQC513203       Michelle Fisher         Female             41-50
# VVC435406          Brooke Davis         Female             31-40
# VKT437745         Andrew Graves           Male              0-10
# VJG208744        Cody Carpenter           Male             51-64
# VAF235393     Christopher White         Female             31-40
# ...                         ...            ...               ...
# VYV246792         Kenneth Smith           Male              0-10
# VBO082144         Kristin Jones         Female             51-64
# VKA771318  Christopher Williams         Female             51-64
# VQZ422704       Pamela Mcgee MD         Female              0-10
# VCG668375             Beth Ross           Male             41-50
#
#           Patient Blood Type Patient Insurance Number  Patient Phone  \
# Visit ID
# VQC513203                 O-               G264037622    15786233257
# VVC435406                 O+               Y133547589    16238255302
# VKT437745                 O+               F115599209    17550508440
# VJG208744                AB+               W720918648    15210588122
# VAF235393                 A+               Q198981012    16561784363
# ...                      ...                      ...            ...
# VYV246792                 B+               H797815344    17316183697
# VBO082144                AB+               Z982649988    17953227317
# VKA771318                AB+                  Private    16951975501
# VQZ422704                 A+               L605331052    15918361501
# VCG668375                 O-               J503309960    17141962660
#
#                                    Patient Address  \
# Visit ID
# VQC513203  Pärtzeltweg 2\n22301 Neunburg vorm Wald
# VVC435406    Kira-Gorlitz-Allee 8\n67100 Rosenheim
# VKT437745              Thiesstr. 3/5\n68745 Bremen
# VJG208744          Schmidtkeallee 53\n54913 Siegen
# VAF235393     Ida-Fliegner-Ring 7/6\n53118 Wolgast
# ...                                            ...
# VYV246792   Steinbergstr. 5/9\n43481 Ebermannstadt
# VBO082144             Beckerplatz 0\n46198 Beeskow
# VKA771318        Fiebigplatz 5\n26886 Fürstenwalde
# VQZ422704          Mielcarekplatz 1/9\n83357 Melle
# VCG668375             Hofmannweg 06\n38230 Hagenow
#
#                          Patient Occupation       Patient Emergency Contact  \
# Visit ID
# VQC513203                Surveyor, quantity  Jennifer Bailey, 015680180768.
# VVC435406                              Copy   Dennis Carlson, 015182104709.
# VKT437745         Claims inspector/assessor  Veronica Harris, 015034485673.
# VJG208744                   Tourism officer  Michelle Graham, 017438105819.
# VAF235393             Engineering geologist      Peter Stout, 015017527431.
# ...                                     ...                             ...
# VYV246792                 Librarian, public  Steven Caldwell, 015315613798.
# VBO082144                     Site engineer    Scott Simpson, 016581707368.
# VKA771318               Chemist, analytical    James Farrell, 015303912796.
# VQZ422704  Scientific laboratory technician    Michael Weiss, 017716313028.
# VCG668375            Pension scheme manager   Pamela English, 017505981536.
#
#                                                  Description
# Visit ID
# VQC513203  The patient presented with chronic lower back ...
# VVC435406  The patient presented with symptoms of fatigue...
# VKT437745  The patient presented with delayed speech deve...
# VJG208744  The patient presented with symptoms of muscle ...
# VAF235393  The patient presented with a diagnosis of brea...
# ...                                                      ...
# VYV246792  Today I met with a young patient who was broug...
# VBO082144  The patient presented with symptoms of persist...
# VKA771318  The patient presented with symptoms of severe ...
# VQZ422704  Today I saw a patient with a chromosomal anoma...
# VCG668375  I saw a patient in the emergency room today wi...
#
# [11689 rows x 18 columns]

# %%
re_order = [
    'Description', 'Visit Date', 'Patient ID', 'Diagnosis Category', 
    'Diagnosis Sub Category', 'Treatment Category', 'Treatment Sub Category', 
    'New Patient', 'Consulting Physician', 'Patient Name', 'Patient Gender', 
    'Patient Age Range', 'Patient Blood Type', 'Patient Insurance Number', 
    'Patient Phone', 'Patient Address', 'Patient Occupation', 'Patient Emergency Contact'
]
df_3 = df_3[re_order]
df_3
# Out:
#                                                  Description  Visit Date  \
# Visit ID
# VQC513203  The patient presented with chronic lower back ...  2017-01-01
# VVC435406  The patient presented with symptoms of fatigue...  2017-01-01
# VKT437745  The patient presented with delayed speech deve...  2017-01-01
# VJG208744  The patient presented with symptoms of muscle ...  2017-01-01
# VAF235393  The patient presented with a diagnosis of brea...  2017-01-01
# ...                                                      ...         ...
# VYV246792  Today I met with a young patient who was broug...  2018-12-30
# VBO082144  The patient presented with symptoms of persist...  2018-12-30
# VKA771318  The patient presented with symptoms of severe ...  2018-12-30
# VQZ422704  Today I saw a patient with a chromosomal anoma...  2018-12-30
# VCG668375  I saw a patient in the emergency room today wi...  2018-12-30
#
#           Patient ID                     Diagnosis Category  \
# Visit ID
# VQC513203  PZM508653                           Chronic Pain
# VVC435406  PSN036517                   Endocrine/ Metabolic
# VKT437745  PPD253419                             Pediatrics
# VJG208744  PBN488954  Central Nervous System/ Neuromuscular
# VAF235393  PJG173047                                 Cancer
# ...              ...                                    ...
# VYV246792  PBM172577                             Pediatrics
# VBO082144  PVI648420                                 Mental
# VKA771318  PDB455996                   Endocrine/ Metabolic
# VQZ422704  PFS771409                                Genetic
# VCG668375  PFN080564                     Ears, Nose, Throat
#
#            Diagnosis Sub Category  \
# Visit ID
# VQC513203  Vertebral Disc Problem
# VVC435406      Hormone Deficiency
# VKT437745          Delayed Speech
# VJG208744                     NaN
# VAF235393           Breast Cancer
# ...                           ...
# VYV246792          Delayed Speech
# VBO082144              Depression
# VKA771318        Thyroid Problems
# VQZ422704   Chromosomal Anomalies
# VCG668375            Otitis Media
#
#                                       Treatment Category  \
# Visit ID
# VQC513203                    Pharmacy/Prescription Drugs
# VVC435406                    Pharmacy/Prescription Drugs
# VKT437745           Rehabilitation Services - Outpatient
# VJG208744                    Pharmacy/Prescription Drugs
# VAF235393                               Cancer Treatment
# ...                                                  ...
# VYV246792           Rehabilitation Services - Outpatient
# VBO082144  Electrical/ Thermal/ Radiofreq. Interventions
# VKA771318            Acute Medical Services - Outpatient
# VQZ422704                    Pharmacy/Prescription Drugs
# VCG668375            Acute Medical Services - Outpatient
#
#           Treatment Sub Category  New Patient   Consulting Physician  \
# Visit ID
# VQC513203   Non-FDA Approved Use         True      Dr. Jerry Daniels
# VVC435406               Hormones         True      Dr. Michelle Lamb
# VKT437745         Speech Therapy         True      Dr. Michelle Lamb
# VJG208744   Non-FDA Approved Use         True       Dr. James Barber
# VAF235393                Surgery         True       Dr. James Barber
# ...                          ...          ...                    ...
# VYV246792         Speech Therapy        False       Dr. James Barber
# VBO082144                    NaN        False  Dr. Alexandria Gaines
# VKA771318         Emergency Room        False      Dr. Michelle Lamb
# VQZ422704               Hormones        False       Dr. James Barber
# VCG668375         Emergency Room        False      Dr. Michelle Lamb
#
#                    Patient Name Patient Gender Patient Age Range  \
# Visit ID
# VQC513203       Michelle Fisher         Female             41-50
# VVC435406          Brooke Davis         Female             31-40
# VKT437745         Andrew Graves           Male              0-10
# VJG208744        Cody Carpenter           Male             51-64
# VAF235393     Christopher White         Female             31-40
# ...                         ...            ...               ...
# VYV246792         Kenneth Smith           Male              0-10
# VBO082144         Kristin Jones         Female             51-64
# VKA771318  Christopher Williams         Female             51-64
# VQZ422704       Pamela Mcgee MD         Female              0-10
# VCG668375             Beth Ross           Male             41-50
#
#           Patient Blood Type Patient Insurance Number  Patient Phone  \
# Visit ID
# VQC513203                 O-               G264037622    15786233257
# VVC435406                 O+               Y133547589    16238255302
# VKT437745                 O+               F115599209    17550508440
# VJG208744                AB+               W720918648    15210588122
# VAF235393                 A+               Q198981012    16561784363
# ...                      ...                      ...            ...
# VYV246792                 B+               H797815344    17316183697
# VBO082144                AB+               Z982649988    17953227317
# VKA771318                AB+                  Private    16951975501
# VQZ422704                 A+               L605331052    15918361501
# VCG668375                 O-               J503309960    17141962660
#
#                                    Patient Address  \
# Visit ID
# VQC513203  Pärtzeltweg 2\n22301 Neunburg vorm Wald
# VVC435406    Kira-Gorlitz-Allee 8\n67100 Rosenheim
# VKT437745              Thiesstr. 3/5\n68745 Bremen
# VJG208744          Schmidtkeallee 53\n54913 Siegen
# VAF235393     Ida-Fliegner-Ring 7/6\n53118 Wolgast
# ...                                            ...
# VYV246792   Steinbergstr. 5/9\n43481 Ebermannstadt
# VBO082144             Beckerplatz 0\n46198 Beeskow
# VKA771318        Fiebigplatz 5\n26886 Fürstenwalde
# VQZ422704          Mielcarekplatz 1/9\n83357 Melle
# VCG668375             Hofmannweg 06\n38230 Hagenow
#
#                          Patient Occupation       Patient Emergency Contact
# Visit ID
# VQC513203                Surveyor, quantity  Jennifer Bailey, 015680180768.
# VVC435406                              Copy   Dennis Carlson, 015182104709.
# VKT437745         Claims inspector/assessor  Veronica Harris, 015034485673.
# VJG208744                   Tourism officer  Michelle Graham, 017438105819.
# VAF235393             Engineering geologist      Peter Stout, 015017527431.
# ...                                     ...                             ...
# VYV246792                 Librarian, public  Steven Caldwell, 015315613798.
# VBO082144                     Site engineer    Scott Simpson, 016581707368.
# VKA771318               Chemist, analytical    James Farrell, 015303912796.
# VQZ422704  Scientific laboratory technician    Michael Weiss, 017716313028.
# VCG668375            Pension scheme manager   Pamela English, 017505981536.
#
# [11689 rows x 18 columns]

# %%
df_3.to_csv('dataset_3.csv')
