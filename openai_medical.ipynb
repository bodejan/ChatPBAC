# %% [markdown]
# ## Create DB

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()

# %%
import pandas as pd

df = pd.read_csv('./faker/dataset_3.csv', dtype={'Patient Phone': str})
# Change date to YYYYMMDD-interger 
df['Visit Date'] = pd.to_datetime(df['Visit Date']).dt.strftime('%Y%m%d').astype(int)
df
# Out:
#         Visit ID                                        Description  \
# 0      VQC513203  The patient presented with chronic lower back ...
# 1      VVC435406  The patient presented with symptoms of fatigue...
# 2      VKT437745  The patient presented with delayed speech deve...
# 3      VJG208744  The patient presented with symptoms of muscle ...
# 4      VAF235393  The patient presented with a diagnosis of brea...
# ...          ...                                                ...
# 11684  VTL998110  Today, I met with a patient who was diagnosed ...
# 11685  VLH032189  The patient was diagnosed with liver cancer af...
# 11686  VQZ422704  Today I saw a patient with a chromosomal anoma...
# 11687  VUT814433  The patient presented with symptoms of persist...
# 11688  VCG668375  I saw a patient in the emergency room today wi...
#
#        Visit Date Patient ID                     Diagnosis Category  \
# 0        20170101  PZM508653                           Chronic Pain
# 1        20170101  PSN036517                   Endocrine/ Metabolic
# 2        20170101  PPD253419                             Pediatrics
# 3        20170101  PBN488954  Central Nervous System/ Neuromuscular
# 4        20170101  PJG173047                                 Cancer
# ...           ...        ...                                    ...
# 11684    20181230  PND058072                                 Mental
# 11685    20181230  PPC895292                                 Cancer
# 11686    20181230  PFS771409                                Genetic
# 11687    20181230  PVV930449                                 Mental
# 11688    20181230  PFN080564                     Ears, Nose, Throat
#
#        Diagnosis Sub Category                             Treatment Category  \
# 0      Vertebral Disc Problem                    Pharmacy/Prescription Drugs
# 1          Hormone Deficiency                    Pharmacy/Prescription Drugs
# 2              Delayed Speech           Rehabilitation Services - Outpatient
# 3                         NaN                    Pharmacy/Prescription Drugs
# 4               Breast Cancer                               Cancer Treatment
# ...                       ...                                            ...
# 11684              Depression  Electrical/ Thermal/ Radiofreq. Interventions
# 11685            Liver Cancer                              Special Procedure
# 11686   Chromosomal Anomalies                    Pharmacy/Prescription Drugs
# 11687                     NaN                                            NaN
# 11688            Otitis Media            Acute Medical Services - Outpatient
#
#                   Treatment Sub Category  New Patient   Consulting Physician  \
# 0                   Non-FDA Approved Use         True      Dr. Jerry Daniels
# 1                               Hormones         True      Dr. Michelle Lamb
# 2                         Speech Therapy         True      Dr. Michelle Lamb
# 3                   Non-FDA Approved Use         True       Dr. James Barber
# 4                                Surgery         True       Dr. James Barber
# ...                                  ...          ...                    ...
# 11684  Transcranial Magnetic Stimulation        False  Dr. Alexandria Gaines
# 11685                                NaN        False        Dr. Eddie Young
# 11686                           Hormones        False       Dr. James Barber
# 11687                                NaN         True        Dr. Eddie Young
# 11688                     Emergency Room        False      Dr. Michelle Lamb
#
#        ... Patient Gender Patient Age  Patient Age Range Patient Blood Type  \
# 0      ...         Female          43              41-50                 O-
# 1      ...         Female          36              31-40                 O+
# 2      ...           Male           5               0-10                 O+
# 3      ...           Male          52              51-64                AB+
# 4      ...         Female          36              31-40                 A+
# ...    ...            ...         ...                ...                ...
# 11684  ...           Male          51              51-64                 A-
# 11685  ...           Male          62              51-64                 B-
# 11686  ...         Female           7               0-10                 A+
# 11687  ...         Female          16              10-20                 A+
# 11688  ...           Male          46              41-50                 O-
#
#       Patient Insurance Number Patient Phone  \
# 0                   G264037622  017588215469
# 1                   Y133547589  015087781378
# 2                   F115599209  016368315207
# 3                   W720918648  016217695326
# 4                   Q198981012  017645195473
# ...                        ...           ...
# 11684                  Private  016976645290
# 11685               Q100759966  016394851011
# 11686               L605331052  016453400773
# 11687               G215159968  017155908480
# 11688               J503309960  017188035742
#
#                                          Patient Address  \
# 0                Pärtzeltweg 2\n22301 Neunburg vorm Wald
# 1                  Kira-Gorlitz-Allee 8\n67100 Rosenheim
# 2                            Thiesstr. 3/5\n68745 Bremen
# 3                        Schmidtkeallee 53\n54913 Siegen
# 4                   Ida-Fliegner-Ring 7/6\n53118 Wolgast
# ...                                                  ...
# 11684  Wolfram-auch Schlauchin-Ring 3/3\n94816 Neuruppin
# 11685                     Sölzerring 05\n21768 Altötting
# 11686                    Mielcarekplatz 1/9\n83357 Melle
# 11687                  Dussen vangasse 501\n61560 Aachen
# 11688                       Hofmannweg 06\n38230 Hagenow
#
#                       Patient Occupation       Patient Emergency Contact  \
# 0                     Surveyor, quantity  Jennifer Bailey, 015680180768.
# 1                                   Copy   Dennis Carlson, 015182104709.
# 2              Claims inspector/assessor  Veronica Harris, 015034485673.
# 3                        Tourism officer  Michelle Graham, 017438105819.
# 4                  Engineering geologist      Peter Stout, 015017527431.
# ...                                  ...                             ...
# 11684  Research officer, political party    Emily Garrett, 016593887796.
# 11685                Engineer, petroleum     Linda Flores, 016973980632.
# 11686   Scientific laboratory technician    Michael Weiss, 017716313028.
# 11687            Data processing manager    Tammy Whitney, 017700151177.
# 11688             Pension scheme manager   Pamela English, 017505981536.
#
#                                        Intended Purposes
# 0      ['Care', 'Research', 'Insurance', 'Support', '...
# 1      ['Care', 'Research', 'Insurance', 'Support', '...
# 2      ['Care', 'Research', 'Insurance', 'Support', '...
# 3      ['Care', 'Research', 'Insurance', 'Support', '...
# 4      ['Care', 'Research', 'Insurance', 'Support', '...
# ...                                                  ...
# 11684  ['Care', 'Research', 'Insurance', 'Support', '...
# 11685  ['Care', 'Insurance', 'Support', 'Public', 'Tr...
# 11686  ['Care', 'Research', 'Insurance', 'Support', '...
# 11687  ['Care', 'Research', 'Insurance', 'Support', '...
# 11688  ['Care', 'Research', 'Insurance', 'Support', '...
#
# [11689 rows x 21 columns]

# %%
from langchain_core.documents import Document

def generate_db_docs(df, page_content_column, limit = None):
    if limit is not None:
        df = df.iloc[:limit]

    # Ensure the specified page_content_column exists in the DataFrame
    if page_content_column not in df.columns:
        raise ValueError(f"{page_content_column} does not exist in the DataFrame.")

    docs = []
    cols = list(df.columns)

    for row in df.itertuples(index=False, name=None):
        # Dynamically get the page content using the column name
        page_content_index = cols.index(page_content_column)
        page_content = row[page_content_index]

        # Construct metadata dictionary from the rest of the columns
        metadata = {col: row[cols.index(col)] for col in cols if col != page_content_column}

        # Create Document object and append to docs list
        docs.append(Document(page_content=page_content, metadata=metadata))

    return docs

docs = generate_db_docs(df, 'Description', 1000)

# %%
from langchain.chains.query_constructor.base import AttributeInfo

metadata_field_info = [
    AttributeInfo(
        name="Visit ID",
        description="Unique ID for patient visting a medical center.",
        type="string",
    ),
    AttributeInfo(
        name="Visit Date",
        description="The date the visit to the medical center took place. Format: YYYYMMDD.",
        type="integer",
    ),
    AttributeInfo(
        name="Patient ID",
        description="The ID corresponding to a patient. A patient might visit multiple times, therefore the ID is not unique.",
        type="string",
    ),
    AttributeInfo(
        name="Diagnosis Category", 
        description="Category for medical diagnosis.", 
        type="string"
    ),
    AttributeInfo(
        name="Diagnosis Sub Category", 
        description="Sub category for medical diagnosis.", 
        type="string"
    ),
    AttributeInfo(
        name="Treatment Category", 
        description="Category for medical treatment based on diganosis.", 
        type="string"
    ),
    AttributeInfo(
        name="Treatment Sub Category", 
        description="Sub category for medical treatment based on diganosis.", 
        type="string"
    ),
    AttributeInfo(
        name="New Patient", 
        description="A flag indicating if it is the first time a patient is visiting the medical center. 'True' if it is the first time, 'False' if not.", 
        type="boolean"
    ),
    AttributeInfo(
        name="Consulting Physician", 
        description="The name of the consulting physician. Availbale options: 'Dr. Jerry Daniels', 'Dr. Michelle Lamb', 'Dr. James Barber', 'Dr. Shelly Hunt', 'Dr. Alexandria Gaines', 'Dr. Eddie Young'.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Name", 
        description="The name of the patient seeking medical assistance.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Gender", 
        description="The gender of the patient seeking medical assistance. Available options: 'Female', 'Male', 'Other'.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Age", 
        description="The age of the patient seeking medical assistance.", 
        type="integer"
    ),
    AttributeInfo(
        name="Patient Age Range", 
        description="The age range of the patient seeking medical assistance. Available options: '0-10', '10-20', '21-30', '31-40', '41-50', '51-64', '65+'.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Blood Type", 
        description="The blood type of the patient seeking medical assistance. Available options: 'O-', 'O+', 'AB+', 'A+', 'B+', 'A-', 'B-', 'AB-'.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Insurance Number", 
        description="The insurance number of the patient seeking medical assistance.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Phone", 
        description="The moblie phone number of the patient seeking medical assistance.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Address", 
        description="The address of the patient seeking medical assistance.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Occupation", 
        description="The occupation of the patient seeking medical assistance.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Emergency Contact", 
        description="The emergency contact of the patient seeking medical assistance. The contact includes a name and an address of the emergency contact.", 
        type="string"
    ),
    AttributeInfo(
        name="Intended Purposes", 
        description="A list of intended access purposes for the data generated at the visit to the medical center. The list can contain a set of the following options: 'Care', 'Research', 'Insurance', 'Support', 'Public', 'Trial', 'Product', 'Marketing'.", 
        type="list[string]"
    ),
]

# %% [markdown]
# ## Self-Query

# %%
import os

persist_directory = "./chroma_medical_db"

# Check if the persistence directory exists
if not os.path.exists(persist_directory):
    # If not, create using docs
    os.makedirs(persist_directory, exist_ok=True)
    vectorstore = Chroma.from_documents(docs, OpenAIEmbeddings(), persist_directory=persist_directory)
    print('Creating vectorstore...')
else:
    # If the directory exists, initialize Chroma to use the existing data
    vectorstore = Chroma(persist_directory=persist_directory, embedding_function=OpenAIEmbeddings())
    print('Using existing vectorstore...')
# Out:
# Using existing vectorstore...

# %%
from langchain.retrievers.self_query.base import SelfQueryRetriever
from langchain_openai import ChatOpenAI

document_content_description = "A summary of of a visit at a medical center for the docters perspective. The text includes symptoms dignosis and proposed treatment."
llm = ChatOpenAI(temperature=0)
retriever = SelfQueryRetriever.from_llm(
    llm,
    vectorstore,
    document_content_description,
    metadata_field_info,
    verbose=True,
    return_intermediate_steps=True
    #enable_limit=True,
)

# %%
response = retriever.invoke("Get me all visits with diganosis of cancer.")
response
# Out:
# [Document(page_content='The patient presented with a confirmed diagnosis of skin cancer. They exhibited symptoms such as a persistent, growing skin lesion with irregular borders and changes in color. As part of their cancer treatment plan, I have recommended chemotherapy to target and destroy the cancer cells. I have discussed the potential side effects of chemotherapy with the patient and emphasized the importance of closely monitoring their response to the treatment.', metadata={'Consulting Physician': 'Dr. Jerry Daniels', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Skin Cancer', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Trial']", 'New Patient': True, 'Patient Address': 'Adolfine-Dobes-Platz 2/2\n06040 Freital', 'Patient Age': 61, 'Patient Age Range': '51-64', 'Patient Blood Type': 'A+', 'Patient Emergency Contact': 'Joseph Russell, 015748674955.', 'Patient Gender': 'Female', 'Patient ID': 'PZJ572884', 'Patient Insurance Number': 'G238368884', 'Patient Name': 'Tara Cardenas', 'Patient Occupation': 'Public relations officer', 'Patient Phone': '017912901414', 'Treatment Category': 'Cancer Treatment', 'Treatment Sub Category': 'Chemotherapy', 'Visit Date': 20170120, 'Visit ID': 'VYF479318'}),
#  Document(page_content='The patient was diagnosed with breast cancer after presenting with a palpable lump in the breast, skin changes over the affected area, and nipple discharge. Following the diagnosis, the treatment plan involved chemotherapy to target and destroy cancer cells throughout the body. The patient was informed about the potential side effects of chemotherapy, such as hair loss, nausea, and fatigue, and was scheduled to start the treatment regimen to combat the cancer.', metadata={'Consulting Physician': 'Dr. Jerry Daniels', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Breast Cancer', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Trial', 'Product']", 'New Patient': True, 'Patient Address': 'Karzstraße 515\n03321 Jessen', 'Patient Age': 4, 'Patient Age Range': '0-10', 'Patient Blood Type': 'O-', 'Patient Emergency Contact': 'Jonathan Mooney, 015445373846.', 'Patient Gender': 'Other', 'Patient ID': 'PGZ401290', 'Patient Insurance Number': 'I153415849', 'Patient Name': 'John Chavez', 'Patient Occupation': 'Production assistant, radio', 'Patient Phone': '016249274246', 'Treatment Category': 'Cancer Treatment', 'Treatment Sub Category': 'Chemotherapy', 'Visit Date': 20170216, 'Visit ID': 'VDM013641'}),
#  Document(page_content='I referred the patient to an oncologist for a specialty consultation regarding their cancer diagnosis.', metadata={'Consulting Physician': 'Dr. Jerry Daniels', 'Diagnosis Category': 'Cancer', 'Intended Purposes': "['Care', 'Insurance', 'Support', 'Product']", 'New Patient': False, 'Patient Address': 'Fliegnerstr. 01\n49748 Geithain', 'Patient Age': 60, 'Patient Age Range': '51-64', 'Patient Blood Type': 'B+', 'Patient Emergency Contact': 'Lydia Cabrera, 017066227177.', 'Patient Gender': 'Male', 'Patient ID': 'PKW753768', 'Patient Insurance Number': 'M970494768', 'Patient Name': 'Steven Johnston', 'Patient Occupation': 'Horticulturist, commercial', 'Patient Phone': '015637915655', 'Treatment Category': 'Diagnostic/Physician Evaluation', 'Treatment Sub Category': 'Specialty Consultation Referral', 'Visit Date': 20170211, 'Visit ID': 'VZT743876'}),
#  Document(page_content='The patient presented with a suspicious mole that was later diagnosed as skin cancer. The treatment plan involved initiating chemotherapy to target and eradicate the cancerous cells. The patient was informed about the potential side effects of chemotherapy and the importance of adhering to the treatment schedule for optimal outcomes. Follow-up appointments were scheduled to monitor the response to the chemotherapy and adjust the treatment plan as needed.', metadata={'Consulting Physician': 'Dr. Alexandria Gaines', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Skin Cancer', 'Intended Purposes': "['Care', 'Insurance', 'Support', 'Public', 'Trial']", 'New Patient': True, 'Patient Address': 'Oestrovskyallee 2\n51854 Hildburghausen', 'Patient Age': 59, 'Patient Age Range': '51-64', 'Patient Blood Type': 'O+', 'Patient Emergency Contact': 'Barbara Thompson, 017647870088.', 'Patient Gender': 'Male', 'Patient ID': 'PGD755392', 'Patient Insurance Number': 'V542258607', 'Patient Name': 'Lisa Williams', 'Patient Occupation': 'Designer, multimedia', 'Patient Phone': '015320722099', 'Treatment Category': 'Cancer Treatment', 'Treatment Sub Category': 'Chemotherapy', 'Visit Date': 20170103, 'Visit ID': 'VZA334395'})]

# %%
response = retriever.invoke("Get me patients that allow data access for research.")
response
# Out:
# [Document(page_content='The patient has been diagnosed with breast cancer. They are being considered for an investigational treatment as part of their cancer treatment plan. This treatment approach involves exploring innovative therapies that are still undergoing clinical trials and research. The goal is to provide the patient with access to cutting-edge treatments that may offer promising results in their fight against breast cancer. Close monitoring and participation in research protocols will be essential throughout the course of this investigational treatment.', metadata={'Consulting Physician': 'Dr. Shelly Hunt', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Breast Cancer', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support']", 'New Patient': True, 'Patient Address': 'Schmiedtallee 8/5\n56041 Chemnitz', 'Patient Age': 53, 'Patient Age Range': '51-64', 'Patient Blood Type': 'B+', 'Patient Emergency Contact': 'Dr. Christopher Pennington DDS, 015314134358.', 'Patient Gender': 'Female', 'Patient ID': 'PNP273262', 'Patient Insurance Number': 'F975112557', 'Patient Name': 'Paul Reyes', 'Patient Occupation': 'Ceramics designer', 'Patient Phone': '016486894334', 'Treatment Category': 'Cancer Treatment', 'Treatment Sub Category': 'Investigational Treatment', 'Visit Date': 20170211, 'Visit ID': 'VHS853335'}),
#  Document(page_content='I met with a patient diagnosed with skin cancer who was enrolled in a clinical trial for cancer treatment in phases 2-4. We discussed the potential benefits of the trial, including access to cutting-edge therapies and close monitoring of their condition. The patient expressed hope and determination to fight the cancer with this innovative approach. I provided detailed information about the trial protocol and scheduled regular follow-up appointments to closely monitor their progress throughout the treatment process.', metadata={'Consulting Physician': 'Dr. Eddie Young', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Skin Cancer', 'Intended Purposes': "['Care', 'Insurance', 'Support']", 'New Patient': True, 'Patient Address': 'Kästerstr. 6\n87387 Mellrichstadt', 'Patient Age': 53, 'Patient Age Range': '51-64', 'Patient Blood Type': 'O+', 'Patient Emergency Contact': 'Amber Bishop, 015348750137.', 'Patient Gender': 'Female', 'Patient ID': 'PPW876457', 'Patient Insurance Number': 'U697909058', 'Patient Name': 'Jessica Bradshaw', 'Patient Occupation': 'Public relations account executive', 'Patient Phone': '016427937211', 'Treatment Category': 'Cancer Treatment', 'Treatment Sub Category': 'Clinical Trial (Phases 2-4)', 'Visit Date': 20170303, 'Visit ID': 'VPC203664'}),
#  Document(page_content='The patient presented with a diagnosis of breast cancer. After discussing various treatment options, including surgery, chemotherapy, and radiation therapy, we decided to explore the possibility of enrolling the patient in an investigational treatment trial. This treatment approach involves novel therapies that may offer promising results in targeting the specific type of breast cancer the patient has. We thoroughly discussed the potential risks and benefits of participating in the trial, and the patient expressed interest in pursuing this option to potentially improve their prognosis.', metadata={'Consulting Physician': 'Dr. Eddie Young', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Breast Cancer', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Public', 'Trial']", 'New Patient': True, 'Patient Address': 'Wilmsstr. 84\n61252 Grevenbroich', 'Patient Age': 43, 'Patient Age Range': '41-50', 'Patient Blood Type': 'A+', 'Patient Emergency Contact': 'Alicia Rhodes, 017759514791.', 'Patient Gender': 'Female', 'Patient ID': 'PTY486778', 'Patient Insurance Number': 'F329584745', 'Patient Name': 'Mr. Jacob Long', 'Patient Occupation': 'Physicist, medical', 'Patient Phone': '017662176145', 'Treatment Category': 'Cancer Treatment', 'Treatment Sub Category': 'Investigational Treatment', 'Visit Date': 20170205, 'Visit ID': 'VCD170500'}),
#  Document(page_content='The patient has been diagnosed with breast cancer. They are currently undergoing investigational treatment as part of their cancer treatment plan. The goal is to explore new and innovative approaches to managing their condition and improve their chances of successful outcomes. Close monitoring and regular assessments will be conducted to track the effectiveness of this investigational treatment.', metadata={'Consulting Physician': 'Dr. James Barber', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Breast Cancer', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Product']", 'New Patient': True, 'Patient Address': 'Henny-Bohlander-Gasse 536\n17817 Hagenow', 'Patient Age': 54, 'Patient Age Range': '51-64', 'Patient Blood Type': 'AB+', 'Patient Emergency Contact': 'Michelle Rivera, 015169080560.', 'Patient Gender': 'Female', 'Patient ID': 'PDM236997', 'Patient Insurance Number': 'P146996041', 'Patient Name': 'Rhonda Garcia', 'Patient Occupation': 'Development worker, international aid', 'Patient Phone': '017719171267', 'Treatment Category': 'Cancer Treatment', 'Treatment Sub Category': 'Investigational Treatment', 'Visit Date': 20170107, 'Visit ID': 'VDW581539'})]

# %%
response = retriever.invoke("Get me patients with blood type A-")
response
# Out:
# [Document(page_content='Today I met with a patient diagnosed with advanced lung cancer. We discussed the option of enrolling in an investigational treatment program as part of their cancer treatment plan. I explained the potential benefits and risks associated with this innovative approach, and the patient expressed interest in exploring this opportunity further. We will continue to closely monitor their condition and progress throughout the course of this investigational treatment.', metadata={'Consulting Physician': 'Dr. Shelly Hunt', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Lung Cancer', 'Intended Purposes': "['Care', 'Insurance', 'Support', 'Public', 'Marketing']", 'New Patient': True, 'Patient Address': 'Kabusgasse 9/4\n03639 Ebersberg', 'Patient Age': 51, 'Patient Age Range': '51-64', 'Patient Blood Type': 'A-', 'Patient Emergency Contact': 'Michael Clark, 015224630202.', 'Patient Gender': 'Male', 'Patient ID': 'PDU358831', 'Patient Insurance Number': 'C614380423', 'Patient Name': 'Laura Duran', 'Patient Occupation': 'Lexicographer', 'Patient Phone': '015622547085', 'Treatment Category': 'Cancer Treatment', 'Treatment Sub Category': 'Investigational Treatment', 'Visit Date': 20170212, 'Visit ID': 'VXO047772'}),
#  Document(page_content="Today I met with a patient who came in for a special procedure requiring general anesthesia as part of their preventive care. The patient was prepared for the anesthesia and the procedure went smoothly. It's great to see individuals taking proactive steps towards maintaining their good health.", metadata={'Consulting Physician': 'Dr. Michelle Lamb', 'Diagnosis Category': 'Prevention/Good Health', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Trial']", 'New Patient': True, 'Patient Address': 'Hänelgasse 21\n91213 Groß-Gerau', 'Patient Age': 51, 'Patient Age Range': '51-64', 'Patient Blood Type': 'A-', 'Patient Emergency Contact': 'Wanda Martin, 017845361522.', 'Patient Gender': 'Female', 'Patient ID': 'PEB985432', 'Patient Insurance Number': 'J268998352', 'Patient Name': 'Eric Lucero', 'Patient Occupation': 'Dance movement psychotherapist', 'Patient Phone': '016941974072', 'Treatment Category': 'Special Procedure', 'Treatment Sub Category': 'General Anesthesia', 'Visit Date': 20170222, 'Visit ID': 'VCD808585'}),
#  Document(page_content='The patient with a diagnosis of breast cancer underwent a PET scan as part of their diagnostic imaging and screening. The scan helped to determine the extent of the cancer spread and assisted in planning the appropriate treatment course.', metadata={'Consulting Physician': 'Dr. Michelle Lamb', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Breast Cancer', 'Intended Purposes': "['Care', 'Insurance', 'Support', 'Trial']", 'New Patient': True, 'Patient Address': 'Fischerplatz 532\n14416 Eichstätt', 'Patient Age': 52, 'Patient Age Range': '51-64', 'Patient Blood Type': 'A-', 'Patient Emergency Contact': 'Kenneth Pineda, 016595293265.', 'Patient Gender': 'Female', 'Patient ID': 'PLH243701', 'Patient Insurance Number': 'U772020752', 'Patient Name': 'Caitlin Rangel', 'Patient Occupation': 'Chartered certified accountant', 'Patient Phone': '015849986727', 'Treatment Category': 'Diagnostic Imaging, Screening and Testing', 'Treatment Sub Category': 'PET Scan', 'Visit Date': 20170129, 'Visit ID': 'VJK441312'}),
#  Document(page_content='The patient presented with symptoms of anxiety and depression, expressing feelings of hopelessness and difficulty coping with daily stressors. After a thorough evaluation, a diagnosis of mixed anxiety and depressive disorder was made. I recommended starting psychotherapy sessions to help the patient explore their thoughts and emotions, develop coping strategies, and work towards improving their overall mental well-being. We discussed the benefits of regular therapy sessions and the importance of consistency in attending appointments to achieve positive outcomes. The patient agreed to begin psychotherapy as part of their mental health treatment plan.', metadata={'Consulting Physician': 'Dr. Jerry Daniels', 'Diagnosis Category': 'Mental', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Trial']", 'New Patient': False, 'Patient Address': 'Berthold-Hermighausen-Allee 70\n44106 Nördlingen', 'Patient Age': 41, 'Patient Age Range': '41-50', 'Patient Blood Type': 'A-', 'Patient Emergency Contact': 'Darrell Webb, 017298555532.', 'Patient Gender': 'Female', 'Patient ID': 'PWX192185', 'Patient Insurance Number': 'Private', 'Patient Name': 'Samuel Ferguson', 'Patient Occupation': 'Make', 'Patient Phone': '015822420016', 'Treatment Category': 'Mental Health Treatment', 'Treatment Sub Category': 'Psychotherapy', 'Visit Date': 20170221, 'Visit ID': 'VDZ606804'})]

# %%
response = retriever.invoke("Get me vists where patients struggle with high blood pressure.")
response
# Out:
# []

# %% [markdown]
# ### Include Query

# %%
from langchain.chains.query_constructor.base import (
    StructuredQueryOutputParser,
    get_query_constructor_prompt,
)

prompt = get_query_constructor_prompt(
    document_content_description,
    metadata_field_info,
)
output_parser = StructuredQueryOutputParser.from_components()
query_constructor = prompt | llm | output_parser

# %%
from langchain.retrievers.self_query.chroma import ChromaTranslator

retriever = SelfQueryRetriever(
    query_constructor=query_constructor,
    vectorstore=vectorstore,
    structured_query_translator=ChromaTranslator(),
)

# %%
print(query_constructor.invoke(
        {
            "query": "Get all patients with any kind of cancer that allow their data to be used to research."
        }
    )
)

print(retriever.invoke(
        "Get all patients with any kind of cancer that allow their data to be used to research."
    )
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain/chains/query_constructor/base.py:56, in StructuredQueryOutputParser.parse(self, text)
#      55 else:
# ---> 56     parsed["filter"] = self.ast_parse(parsed["filter"])
#      57 if not parsed.get("limit"):
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/lark/lark.py:658, in Lark.parse(self, text, start, on_error)
#     641 """Parse the given text, according to the options provided.
#     642
#     643 Parameters:
#    (...)
#     656
#     657 """
# --> 658 return self.parser.parse(text, start=start, on_error=on_error)
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/lark/parser_frontends.py:104, in ParsingFrontend.parse(self, text, start, on_error)
#     103 stream = self._make_lexer_thread(text)
# --> 104 return self.parser.parse(stream, chosen_start, **kw)
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/lark/parsers/lalr_parser.py:42, in LALR_Parser.parse(self, lexer, start, on_error)
#      41 try:
# ---> 42     return self.parser.parse(lexer, start)
#      43 except UnexpectedInput as e:
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/lark/parsers/lalr_parser.py:88, in _Parser.parse(self, lexer, start, value_stack, state_stack, start_interactive)
#      87     return InteractiveParser(self, parser_state, parser_state.lexer)
# ---> 88 return self.parse_from_state(parser_state)
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/lark/parsers/lalr_parser.py:102, in _Parser.parse_from_state(self, state, last_token)
#     101     assert token is not None
# --> 102     state.feed_token(token)
#     104 end_token = Token.new_borrow_pos('$END', '', token) if token else Token('$END', '', 0, 1, 1)
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/lark/parsers/lalr_parser_state.py:101, in ParserState.feed_token(self, token, is_end)
#      99     s = []
# --> 101 value = callbacks[rule](s) if callbacks else s
#     103 _action, new_state = states[state_stack[-1]][rule.origin.name]
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/lark/parse_tree_builder.py:155, in ChildFilterLALR_NoPlaceholders.__call__(self, children)
#     154         filtered.append(children[i])
# --> 155 return self.node_builder(filtered)
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/lark/parse_tree_builder.py:327, in apply_visit_wrapper.<locals>.f(children)
#     325 @wraps(func)
#     326 def f(children):
# --> 327     return wrapper(func, name, children, None)
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/lark/visitors.py:501, in _vargs_inline(f, _data, children, _meta)
#     500 def _vargs_inline(f, _data, children, _meta):
# --> 501     return f(*children)
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/lark/visitors.py:479, in _VArgsWrapper.__call__(self, *args, **kwargs)
#     478 def __call__(self, *args, **kwargs):
# --> 479     return self.base_func(*args, **kwargs)
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain/chains/query_constructor/parser.py:85, in QueryTransformer.func_call(self, func_name, args)
#      84 def func_call(self, func_name: Any, args: list) -> FilterDirective:
# ---> 85     func = self._match_func_name(str(func_name))
#      86     if isinstance(func, Comparator):
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain/chains/query_constructor/parser.py:116, in QueryTransformer._match_func_name(self, func_name)
#     115 else:
# --> 116     raise ValueError(
#     117         f"Received unrecognized function {func_name}. Valid functions are "
#     118         f"{list(Operator) + list(Comparator)}"
#     119     )
#
# ValueError: Received unrecognized function contains. Valid functions are [<Operator.AND: 'and'>, <Operator.OR: 'or'>, <Operator.NOT: 'not'>, <Comparator.EQ: 'eq'>, <Comparator.NE: 'ne'>, <Comparator.GT: 'gt'>, <Comparator.GTE: 'gte'>, <Comparator.LT: 'lt'>, <Comparator.LTE: 'lte'>, <Comparator.CONTAIN: 'contain'>, <Comparator.LIKE: 'like'>, <Comparator.IN: 'in'>, <Comparator.NIN: 'nin'>]
#
# During handling of the above exception, another exception occurred:
#
# OutputParserException                     Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 print(query_constructor.invoke(
#       2         {
#       3             "query": "Get all patients with any kind of cancer that allow their data to be used to research."
#       4         }
#       5     )
#       6 )
#       8 print(retriever.invoke(
#       9         "Get all patients with any kind of cancer that allow their data to be used to research."
#      10     )
#      11 )
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain_core/runnables/base.py:2309, in RunnableSequence.invoke(self, input, config)
#    2307 try:
#    2308     for i, step in enumerate(self.steps):
# -> 2309         input = step.invoke(
#    2310             input,
#    2311             # mark each step as a child run
#    2312             patch_config(
#    2313                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    2314             ),
#    2315         )
#    2316 # finish the root run
#    2317 except BaseException as e:
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain_core/output_parsers/base.py:169, in BaseOutputParser.invoke(self, input, config)
#     165 def invoke(
#     166     self, input: Union[str, BaseMessage], config: Optional[RunnableConfig] = None
#     167 ) -> T:
#     168     if isinstance(input, BaseMessage):
# --> 169         return self._call_with_config(
#     170             lambda inner_input: self.parse_result(
#     171                 [ChatGeneration(message=inner_input)]
#     172             ),
#     173             input,
#     174             config,
#     175             run_type="parser",
#     176         )
#     177     else:
#     178         return self._call_with_config(
#     179             lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     180             input,
#     181             config,
#     182             run_type="parser",
#     183         )
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain_core/runnables/base.py:1488, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#    1484     context = copy_context()
#    1485     context.run(var_child_runnable_config.set, child_config)
#    1486     output = cast(
#    1487         Output,
# -> 1488         context.run(
#    1489             call_func_with_variable_args,  # type: ignore[arg-type]
#    1490             func,  # type: ignore[arg-type]
#    1491             input,  # type: ignore[arg-type]
#    1492             config,
#    1493             run_manager,
#    1494             **kwargs,
#    1495         ),
#    1496     )
#    1497 except BaseException as e:
#    1498     run_manager.on_chain_error(e)
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain_core/runnables/config.py:347, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     345 if run_manager is not None and accepts_run_manager(func):
#     346     kwargs["run_manager"] = run_manager
# --> 347 return func(input, **kwargs)
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain_core/output_parsers/base.py:170, in BaseOutputParser.invoke.<locals>.<lambda>(inner_input)
#     165 def invoke(
#     166     self, input: Union[str, BaseMessage], config: Optional[RunnableConfig] = None
#     167 ) -> T:
#     168     if isinstance(input, BaseMessage):
#     169         return self._call_with_config(
# --> 170             lambda inner_input: self.parse_result(
#     171                 [ChatGeneration(message=inner_input)]
#     172             ),
#     173             input,
#     174             config,
#     175             run_type="parser",
#     176         )
#     177     else:
#     178         return self._call_with_config(
#     179             lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     180             input,
#     181             config,
#     182             run_type="parser",
#     183         )
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain_core/output_parsers/base.py:221, in BaseOutputParser.parse_result(self, result, partial)
#     208 def parse_result(self, result: List[Generation], *, partial: bool = False) -> T:
#     209     """Parse a list of candidate model Generations into a specific format.
#     210
#     211     The return value is parsed from only the first Generation in the result, which
#    (...)
#     219         Structured output.
#     220     """
# --> 221     return self.parse(result[0].text)
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain/chains/query_constructor/base.py:63, in StructuredQueryOutputParser.parse(self, text)
#      59     return StructuredQuery(
#      60         **{k: v for k, v in parsed.items() if k in allowed_keys}
#      61     )
#      62 except Exception as e:
# ---> 63     raise OutputParserException(
#      64         f"Parsing text\n{text}\n raised following error:\n{e}"
#      65     )
#
# OutputParserException: Parsing text
# ```json
# {
#     "query": "cancer",
#     "filter": "and(contains(\"Diagnosis Category\", \"cancer\"), in(\"Intended Purposes\", [\"Research\"]))"
# }
# ```
#  raised following error:
# Received unrecognized function contains. Valid functions are [<Operator.AND: 'and'>, <Operator.OR: 'or'>, <Operator.NOT: 'not'>, <Comparator.EQ: 'eq'>, <Comparator.NE: 'ne'>, <Comparator.GT: 'gt'>, <Comparator.GTE: 'gte'>, <Comparator.LT: 'lt'>, <Comparator.LTE: 'lte'>, <Comparator.CONTAIN: 'contain'>, <Comparator.LIKE: 'like'>, <Comparator.IN: 'in'>, <Comparator.NIN: 'nin'>]

# %%
retriever.invoke(
    "Get all patients with cancer that allow their data to be used to research."
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 retriever.invoke(
#       2     "Get all patients with cancer that allow their data to be used to research."
#       3 )
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain_core/retrievers.py:141, in BaseRetriever.invoke(self, input, config, **kwargs)
#     137 def invoke(
#     138     self, input: str, config: Optional[RunnableConfig] = None, **kwargs: Any
#     139 ) -> List[Document]:
#     140     config = ensure_config(config)
# --> 141     return self.get_relevant_documents(
#     142         input,
#     143         callbacks=config.get("callbacks"),
#     144         tags=config.get("tags"),
#     145         metadata=config.get("metadata"),
#     146         run_name=config.get("run_name"),
#     147         **kwargs,
#     148     )
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain_core/retrievers.py:245, in BaseRetriever.get_relevant_documents(self, query, callbacks, tags, metadata, run_name, **kwargs)
#     243 except Exception as e:
#     244     run_manager.on_retriever_error(e)
# --> 245     raise e
#     246 else:
#     247     run_manager.on_retriever_end(
#     248         result,
#     249     )
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain_core/retrievers.py:238, in BaseRetriever.get_relevant_documents(self, query, callbacks, tags, metadata, run_name, **kwargs)
#     236 _kwargs = kwargs if self._expects_other_args else {}
#     237 if self._new_arg_supported:
# --> 238     result = self._get_relevant_documents(
#     239         query, run_manager=run_manager, **_kwargs
#     240     )
#     241 else:
#     242     result = self._get_relevant_documents(query, **_kwargs)
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain/retrievers/self_query/base.py:189, in SelfQueryRetriever._get_relevant_documents(self, query, run_manager)
#     187 if self.verbose:
#     188     logger.info(f"Generated Query: {structured_query}")
# --> 189 new_query, search_kwargs = self._prepare_query(query, structured_query)
#     190 docs = self._get_docs_with_query(new_query, search_kwargs)
#     191 return docs
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain/retrievers/self_query/base.py:151, in SelfQueryRetriever._prepare_query(self, query, structured_query)
#     148 def _prepare_query(
#     149     self, query: str, structured_query: StructuredQuery
#     150 ) -> Tuple[str, Dict[str, Any]]:
# --> 151     new_query, new_kwargs = self.structured_query_translator.visit_structured_query(
#     152         structured_query
#     153     )
#     154     if structured_query.limit is not None:
#     155         new_kwargs["k"] = structured_query.limit
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain/retrievers/self_query/chroma.py:49, in ChromaTranslator.visit_structured_query(self, structured_query)
#      47     kwargs = {}
#      48 else:
# ---> 49     kwargs = {"filter": structured_query.filter.accept(self)}
#      50 return structured_query.query, kwargs
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain/chains/query_constructor/ir.py:67, in Expr.accept(self, visitor)
#      58 def accept(self, visitor: Visitor) -> Any:
#      59     """Accept a visitor.
#      60
#      61     Args:
#    (...)
#      65         result of visiting
#      66     """
# ---> 67     return getattr(visitor, f"visit_{_to_snake_case(self.__class__.__name__)}")(
#      68         self
#      69     )
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain/retrievers/self_query/chroma.py:33, in ChromaTranslator.visit_operation(self, operation)
#      32 def visit_operation(self, operation: Operation) -> Dict:
# ---> 33     args = [arg.accept(self) for arg in operation.arguments]
#      34     return {self._format_func(operation.operator): args}
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain/retrievers/self_query/chroma.py:33, in <listcomp>(.0)
#      32 def visit_operation(self, operation: Operation) -> Dict:
# ---> 33     args = [arg.accept(self) for arg in operation.arguments]
#      34     return {self._format_func(operation.operator): args}
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain/chains/query_constructor/ir.py:67, in Expr.accept(self, visitor)
#      58 def accept(self, visitor: Visitor) -> Any:
#      59     """Accept a visitor.
#      60
#      61     Args:
#    (...)
#      65         result of visiting
#      66     """
# ---> 67     return getattr(visitor, f"visit_{_to_snake_case(self.__class__.__name__)}")(
#      68         self
#      69     )
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain/retrievers/self_query/chroma.py:39, in ChromaTranslator.visit_comparison(self, comparison)
#      36 def visit_comparison(self, comparison: Comparison) -> Dict:
#      37     return {
#      38         comparison.attribute: {
# ---> 39             self._format_func(comparison.comparator): comparison.value
#      40         }
#      41     }
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain/retrievers/self_query/chroma.py:29, in ChromaTranslator._format_func(self, func)
#      28 def _format_func(self, func: Union[Operator, Comparator]) -> str:
# ---> 29     self._validate_func(func)
#      30     return f"${func.value}"
#
# File ~/PBAC-in-retrieval-augmented-LLMs/venv/lib/python3.8/site-packages/langchain/chains/query_constructor/ir.py:26, in Visitor._validate_func(self, func)
#      24 if isinstance(func, Comparator) and self.allowed_comparators is not None:
#      25     if func not in self.allowed_comparators:
# ---> 26         raise ValueError(
#      27             f"Received disallowed comparator {func}. Allowed "
#      28             f"comparators are {self.allowed_comparators}"
#      29         )
#
# ValueError: Received disallowed comparator in. Allowed comparators are [<Comparator.EQ: 'eq'>, <Comparator.NE: 'ne'>, <Comparator.GT: 'gt'>, <Comparator.GTE: 'gte'>, <Comparator.LT: 'lt'>, <Comparator.LTE: 'lte'>]

# %% [markdown]
# ## QA
#
# https://github.com/insightbuilder/python_de_learners_data/blob/main/code_script_notebooks/projects/exploring_bard/selfQueryingRetriever_QAChains.ipynb
#
# https://www.youtube.com/watch?v=J9mZdEksz3c&t=3s

# %%
import pandas as pd

df = pd.read_csv('./faker/dataset_3.csv', dtype={'Patient Phone': str})
# Change date to YYYYMMDD-interger 
df['Visit Date'] = pd.to_datetime(df['Visit Date']).dt.strftime('%Y%m%d').astype(int)
# Add 'source' column to match later retrievals
df['source'] = df['Visit ID']
df
# Out:
#         Visit ID                                        Description  \
# 0      VQC513203  The patient presented with chronic lower back ...
# 1      VVC435406  The patient presented with symptoms of fatigue...
# 2      VKT437745  The patient presented with delayed speech deve...
# 3      VJG208744  The patient presented with symptoms of muscle ...
# 4      VAF235393  The patient presented with a diagnosis of brea...
# ...          ...                                                ...
# 11684  VTL998110  Today, I met with a patient who was diagnosed ...
# 11685  VLH032189  The patient was diagnosed with liver cancer af...
# 11686  VQZ422704  Today I saw a patient with a chromosomal anoma...
# 11687  VUT814433  The patient presented with symptoms of persist...
# 11688  VCG668375  I saw a patient in the emergency room today wi...
#
#        Visit Date Patient ID                     Diagnosis Category  \
# 0        20170101  PZM508653                           Chronic Pain
# 1        20170101  PSN036517                   Endocrine/ Metabolic
# 2        20170101  PPD253419                             Pediatrics
# 3        20170101  PBN488954  Central Nervous System/ Neuromuscular
# 4        20170101  PJG173047                                 Cancer
# ...           ...        ...                                    ...
# 11684    20181230  PND058072                                 Mental
# 11685    20181230  PPC895292                                 Cancer
# 11686    20181230  PFS771409                                Genetic
# 11687    20181230  PVV930449                                 Mental
# 11688    20181230  PFN080564                     Ears, Nose, Throat
#
#        Diagnosis Sub Category                             Treatment Category  \
# 0      Vertebral Disc Problem                    Pharmacy/Prescription Drugs
# 1          Hormone Deficiency                    Pharmacy/Prescription Drugs
# 2              Delayed Speech           Rehabilitation Services - Outpatient
# 3                         NaN                    Pharmacy/Prescription Drugs
# 4               Breast Cancer                               Cancer Treatment
# ...                       ...                                            ...
# 11684              Depression  Electrical/ Thermal/ Radiofreq. Interventions
# 11685            Liver Cancer                              Special Procedure
# 11686   Chromosomal Anomalies                    Pharmacy/Prescription Drugs
# 11687                     NaN                                            NaN
# 11688            Otitis Media            Acute Medical Services - Outpatient
#
#                   Treatment Sub Category  New Patient   Consulting Physician  \
# 0                   Non-FDA Approved Use         True      Dr. Jerry Daniels
# 1                               Hormones         True      Dr. Michelle Lamb
# 2                         Speech Therapy         True      Dr. Michelle Lamb
# 3                   Non-FDA Approved Use         True       Dr. James Barber
# 4                                Surgery         True       Dr. James Barber
# ...                                  ...          ...                    ...
# 11684  Transcranial Magnetic Stimulation        False  Dr. Alexandria Gaines
# 11685                                NaN        False        Dr. Eddie Young
# 11686                           Hormones        False       Dr. James Barber
# 11687                                NaN         True        Dr. Eddie Young
# 11688                     Emergency Room        False      Dr. Michelle Lamb
#
#        ... Patient Age Patient Age Range  Patient Blood Type  \
# 0      ...          43             41-50                  O-
# 1      ...          36             31-40                  O+
# 2      ...           5              0-10                  O+
# 3      ...          52             51-64                 AB+
# 4      ...          36             31-40                  A+
# ...    ...         ...               ...                 ...
# 11684  ...          51             51-64                  A-
# 11685  ...          62             51-64                  B-
# 11686  ...           7              0-10                  A+
# 11687  ...          16             10-20                  A+
# 11688  ...          46             41-50                  O-
#
#       Patient Insurance Number Patient Phone  \
# 0                   G264037622  017588215469
# 1                   Y133547589  015087781378
# 2                   F115599209  016368315207
# 3                   W720918648  016217695326
# 4                   Q198981012  017645195473
# ...                        ...           ...
# 11684                  Private  016976645290
# 11685               Q100759966  016394851011
# 11686               L605331052  016453400773
# 11687               G215159968  017155908480
# 11688               J503309960  017188035742
#
#                                          Patient Address  \
# 0                Pärtzeltweg 2\n22301 Neunburg vorm Wald
# 1                  Kira-Gorlitz-Allee 8\n67100 Rosenheim
# 2                            Thiesstr. 3/5\n68745 Bremen
# 3                        Schmidtkeallee 53\n54913 Siegen
# 4                   Ida-Fliegner-Ring 7/6\n53118 Wolgast
# ...                                                  ...
# 11684  Wolfram-auch Schlauchin-Ring 3/3\n94816 Neuruppin
# 11685                     Sölzerring 05\n21768 Altötting
# 11686                    Mielcarekplatz 1/9\n83357 Melle
# 11687                  Dussen vangasse 501\n61560 Aachen
# 11688                       Hofmannweg 06\n38230 Hagenow
#
#                       Patient Occupation       Patient Emergency Contact  \
# 0                     Surveyor, quantity  Jennifer Bailey, 015680180768.
# 1                                   Copy   Dennis Carlson, 015182104709.
# 2              Claims inspector/assessor  Veronica Harris, 015034485673.
# 3                        Tourism officer  Michelle Graham, 017438105819.
# 4                  Engineering geologist      Peter Stout, 015017527431.
# ...                                  ...                             ...
# 11684  Research officer, political party    Emily Garrett, 016593887796.
# 11685                Engineer, petroleum     Linda Flores, 016973980632.
# 11686   Scientific laboratory technician    Michael Weiss, 017716313028.
# 11687            Data processing manager    Tammy Whitney, 017700151177.
# 11688             Pension scheme manager   Pamela English, 017505981536.
#
#                                        Intended Purposes     source
# 0      ['Care', 'Research', 'Insurance', 'Support', '...  VQC513203
# 1      ['Care', 'Research', 'Insurance', 'Support', '...  VVC435406
# 2      ['Care', 'Research', 'Insurance', 'Support', '...  VKT437745
# 3      ['Care', 'Research', 'Insurance', 'Support', '...  VJG208744
# 4      ['Care', 'Research', 'Insurance', 'Support', '...  VAF235393
# ...                                                  ...        ...
# 11684  ['Care', 'Research', 'Insurance', 'Support', '...  VTL998110
# 11685  ['Care', 'Insurance', 'Support', 'Public', 'Tr...  VLH032189
# 11686  ['Care', 'Research', 'Insurance', 'Support', '...  VQZ422704
# 11687  ['Care', 'Research', 'Insurance', 'Support', '...  VUT814433
# 11688  ['Care', 'Research', 'Insurance', 'Support', '...  VCG668375
#
# [11689 rows x 22 columns]

# %%
from langchain_core.documents import Document

def generate_db_docs(df, page_content_column, limit = None):
    if limit is not None:
        df = df.iloc[:limit]

    # Ensure the specified page_content_column exists in the DataFrame
    if page_content_column not in df.columns:
        raise ValueError(f"{page_content_column} does not exist in the DataFrame.")

    docs = []
    cols = list(df.columns)

    for row in df.itertuples(index=False, name=None):
        # Dynamically get the page content using the column name
        page_content_index = cols.index(page_content_column)
        page_content = row[page_content_index]

        # Construct metadata dictionary from the rest of the columns
        metadata = {col: row[cols.index(col)] for col in cols if col != page_content_column}

        # Create Document object and append to docs list
        docs.append(Document(page_content=page_content, metadata=metadata))

    return docs

docs = generate_db_docs(df, 'Description', 1000)

# %%
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain.chains.query_constructor.base import AttributeInfo
import os

embeddings = OpenAIEmbeddings()

metadata_field_info = [
    AttributeInfo(
        name="Visit ID",
        description="Unique ID for patient visting a medical center.",
        type="string",
    ),
    AttributeInfo(
        name="Visit Date",
        description="The date the visit to the medical center took place. Format: YYYYMMDD.",
        type="integer",
    ),
    AttributeInfo(
        name="Patient ID",
        description="The ID corresponding to a patient. A patient might visit multiple times, therefore the ID is not unique.",
        type="string",
    ),
    AttributeInfo(
        name="Diagnosis Category", 
        description="Category for medical diagnosis.", 
        type="string"
    ),
    AttributeInfo(
        name="Diagnosis Sub Category", 
        description="Sub category for medical diagnosis.", 
        type="string"
    ),
    AttributeInfo(
        name="Treatment Category", 
        description="Category for medical treatment based on diganosis.", 
        type="string"
    ),
    AttributeInfo(
        name="Treatment Sub Category", 
        description="Sub category for medical treatment based on diganosis.", 
        type="string"
    ),
    AttributeInfo(
        name="New Patient", 
        description="A flag indicating if it is the first time a patient is visiting the medical center. 'True' if it is the first time, 'False' if not.", 
        type="boolean"
    ),
    AttributeInfo(
        name="Consulting Physician", 
        description="The name of the consulting physician. Availbale options: 'Dr. Jerry Daniels', 'Dr. Michelle Lamb', 'Dr. James Barber', 'Dr. Shelly Hunt', 'Dr. Alexandria Gaines', 'Dr. Eddie Young'.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Name", 
        description="The name of the patient seeking medical assistance.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Gender", 
        description="The gender of the patient seeking medical assistance. Available options: 'Female', 'Male', 'Other'.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Age", 
        description="The age of the patient seeking medical assistance.", 
        type="integer"
    ),
    AttributeInfo(
        name="Patient Age Range", 
        description="The age range of the patient seeking medical assistance. Available options: '0-10', '10-20', '21-30', '31-40', '41-50', '51-64', '65+'.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Blood Type", 
        description="The blood type of the patient seeking medical assistance. Available options: 'O-', 'O+', 'AB+', 'A+', 'B+', 'A-', 'B-', 'AB-'.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Insurance Number", 
        description="The insurance number of the patient seeking medical assistance.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Phone", 
        description="The moblie phone number of the patient seeking medical assistance.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Address", 
        description="The address of the patient seeking medical assistance.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Occupation", 
        description="The occupation of the patient seeking medical assistance.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Emergency Contact", 
        description="The emergency contact of the patient seeking medical assistance. The contact includes a name and an address of the emergency contact.", 
        type="string"
    ),
    AttributeInfo(
        name="Intended Purposes", 
        description="A list of intended access purposes for the data generated at the visit to the medical center. The list can contain a set of the following options: 'Care', 'Research', 'Insurance', 'Support', 'Public', 'Trial', 'Product', 'Marketing'.", 
        type="list[string]"
    ),
]

persist_directory = "./chroma_medical_qa_db"

# Check if the persistence directory exists
if not os.path.exists(persist_directory):
    # If not, create using docs
    os.makedirs(persist_directory, exist_ok=True)
    vectorstore = Chroma.from_documents(docs, OpenAIEmbeddings(), persist_directory=persist_directory)
    print('Creating vectorstore...')
else:
    # If the directory exists, initialize Chroma to use the existing data
    vectorstore = Chroma(persist_directory=persist_directory, embedding_function=OpenAIEmbeddings())
    print('Using existing vectorstore...')
# Out:
# Creating vectorstore...

# %%
from langchain.retrievers.self_query.base import SelfQueryRetriever
from langchain_openai import ChatOpenAI

document_content_description = "A summary of of a visit at a medical center for the docters perspective. The text includes symptoms dignosis and proposed treatment."
llm = ChatOpenAI(temperature=0)
retriever = SelfQueryRetriever.from_llm(
    llm,
    vectorstore,
    document_content_description,
    metadata_field_info,
    verbose=True,
    return_intermediate_steps=True
    #enable_limit=True,
)

# %%
from langchain.chains import RetrievalQAWithSourcesChain

chain = RetrievalQAWithSourcesChain.from_chain_type(llm, 
                                                    chain_type="stuff", 
                                                    retriever=retriever)

# %%
chain({"question":"How many male patients have cancer?"}, return_only_outputs=False)
# Out:
# {'question': 'How many male patients have cancer?',
#  'answer': 'The number of male patients with cancer is not specified in the provided content.\n',
#  'sources': ''}

# %%
chain({"question":"What is a common symptom?"}, return_only_outputs=False)
# Out:
# {'question': 'What is a common symptom?',
#  'answer': 'A common symptom is persistent fatigue.\n',
#  'sources': 'VMD613427'}

# %%
chain({"question":"How many male patients visited the medical center?"}, return_only_outputs=False)
# Out:
# {'question': 'How many male patients visited the medical center?',
#  'answer': 'There were 4 male patients who visited the medical center.\n',
#  'sources': 'VYW041077, VAQ243746, VNP039940, VQB689845'}
