# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()

# %%
import pandas as pd

df = pd.read_csv('./faker/dataset_3.csv', dtype={'Patient Phone': str})
# Change date to YYYYMMDD-interger 
df['Visit Date'] = pd.to_datetime(df['Visit Date']).dt.strftime('%Y%m%d').astype(int)
df
# Out:
#         Visit ID                                        Description  \
# 0      VQC513203  The patient presented with chronic lower back ...
# 1      VVC435406  The patient presented with symptoms of fatigue...
# 2      VKT437745  The patient presented with delayed speech deve...
# 3      VJG208744  The patient presented with symptoms of muscle ...
# 4      VAF235393  The patient presented with a diagnosis of brea...
# ...          ...                                                ...
# 11684  VTL998110  Today, I met with a patient who was diagnosed ...
# 11685  VLH032189  The patient was diagnosed with liver cancer af...
# 11686  VQZ422704  Today I saw a patient with a chromosomal anoma...
# 11687  VUT814433  The patient presented with symptoms of persist...
# 11688  VCG668375  I saw a patient in the emergency room today wi...
#
#        Visit Date Patient ID                     Diagnosis Category  \
# 0        20170101  PZM508653                           Chronic Pain
# 1        20170101  PSN036517                   Endocrine/ Metabolic
# 2        20170101  PPD253419                             Pediatrics
# 3        20170101  PBN488954  Central Nervous System/ Neuromuscular
# 4        20170101  PJG173047                                 Cancer
# ...           ...        ...                                    ...
# 11684    20181230  PND058072                                 Mental
# 11685    20181230  PPC895292                                 Cancer
# 11686    20181230  PFS771409                                Genetic
# 11687    20181230  PVV930449                                 Mental
# 11688    20181230  PFN080564                     Ears, Nose, Throat
#
#        Diagnosis Sub Category                             Treatment Category  \
# 0      Vertebral Disc Problem                    Pharmacy/Prescription Drugs
# 1          Hormone Deficiency                    Pharmacy/Prescription Drugs
# 2              Delayed Speech           Rehabilitation Services - Outpatient
# 3                         NaN                    Pharmacy/Prescription Drugs
# 4               Breast Cancer                               Cancer Treatment
# ...                       ...                                            ...
# 11684              Depression  Electrical/ Thermal/ Radiofreq. Interventions
# 11685            Liver Cancer                              Special Procedure
# 11686   Chromosomal Anomalies                    Pharmacy/Prescription Drugs
# 11687                     NaN                                            NaN
# 11688            Otitis Media            Acute Medical Services - Outpatient
#
#                   Treatment Sub Category  New Patient   Consulting Physician  \
# 0                   Non-FDA Approved Use         True      Dr. Jerry Daniels
# 1                               Hormones         True      Dr. Michelle Lamb
# 2                         Speech Therapy         True      Dr. Michelle Lamb
# 3                   Non-FDA Approved Use         True       Dr. James Barber
# 4                                Surgery         True       Dr. James Barber
# ...                                  ...          ...                    ...
# 11684  Transcranial Magnetic Stimulation        False  Dr. Alexandria Gaines
# 11685                                NaN        False        Dr. Eddie Young
# 11686                           Hormones        False       Dr. James Barber
# 11687                                NaN         True        Dr. Eddie Young
# 11688                     Emergency Room        False      Dr. Michelle Lamb
#
#        ... Patient Gender Patient Age  Patient Age Range Patient Blood Type  \
# 0      ...         Female          43              41-50                 O-
# 1      ...         Female          36              31-40                 O+
# 2      ...           Male           5               0-10                 O+
# 3      ...           Male          52              51-64                AB+
# 4      ...         Female          36              31-40                 A+
# ...    ...            ...         ...                ...                ...
# 11684  ...           Male          51              51-64                 A-
# 11685  ...           Male          62              51-64                 B-
# 11686  ...         Female           7               0-10                 A+
# 11687  ...         Female          16              10-20                 A+
# 11688  ...           Male          46              41-50                 O-
#
#       Patient Insurance Number Patient Phone  \
# 0                   G264037622  017588215469
# 1                   Y133547589  015087781378
# 2                   F115599209  016368315207
# 3                   W720918648  016217695326
# 4                   Q198981012  017645195473
# ...                        ...           ...
# 11684                  Private  016976645290
# 11685               Q100759966  016394851011
# 11686               L605331052  016453400773
# 11687               G215159968  017155908480
# 11688               J503309960  017188035742
#
#                                          Patient Address  \
# 0                Pärtzeltweg 2\n22301 Neunburg vorm Wald
# 1                  Kira-Gorlitz-Allee 8\n67100 Rosenheim
# 2                            Thiesstr. 3/5\n68745 Bremen
# 3                        Schmidtkeallee 53\n54913 Siegen
# 4                   Ida-Fliegner-Ring 7/6\n53118 Wolgast
# ...                                                  ...
# 11684  Wolfram-auch Schlauchin-Ring 3/3\n94816 Neuruppin
# 11685                     Sölzerring 05\n21768 Altötting
# 11686                    Mielcarekplatz 1/9\n83357 Melle
# 11687                  Dussen vangasse 501\n61560 Aachen
# 11688                       Hofmannweg 06\n38230 Hagenow
#
#                       Patient Occupation       Patient Emergency Contact  \
# 0                     Surveyor, quantity  Jennifer Bailey, 015680180768.
# 1                                   Copy   Dennis Carlson, 015182104709.
# 2              Claims inspector/assessor  Veronica Harris, 015034485673.
# 3                        Tourism officer  Michelle Graham, 017438105819.
# 4                  Engineering geologist      Peter Stout, 015017527431.
# ...                                  ...                             ...
# 11684  Research officer, political party    Emily Garrett, 016593887796.
# 11685                Engineer, petroleum     Linda Flores, 016973980632.
# 11686   Scientific laboratory technician    Michael Weiss, 017716313028.
# 11687            Data processing manager    Tammy Whitney, 017700151177.
# 11688             Pension scheme manager   Pamela English, 017505981536.
#
#                                        Intended Purposes
# 0      ['Care', 'Research', 'Insurance', 'Support', '...
# 1      ['Care', 'Research', 'Insurance', 'Support', '...
# 2      ['Care', 'Research', 'Insurance', 'Support', '...
# 3      ['Care', 'Research', 'Insurance', 'Support', '...
# 4      ['Care', 'Research', 'Insurance', 'Support', '...
# ...                                                  ...
# 11684  ['Care', 'Research', 'Insurance', 'Support', '...
# 11685  ['Care', 'Insurance', 'Support', 'Public', 'Tr...
# 11686  ['Care', 'Research', 'Insurance', 'Support', '...
# 11687  ['Care', 'Research', 'Insurance', 'Support', '...
# 11688  ['Care', 'Research', 'Insurance', 'Support', '...
#
# [11689 rows x 21 columns]

# %%
from langchain_core.documents import Document

def generate_db_docs(df, page_content_column, limit = None):
    if limit is not None:
        df = df.iloc[:limit]

    # Ensure the specified page_content_column exists in the DataFrame
    if page_content_column not in df.columns:
        raise ValueError(f"{page_content_column} does not exist in the DataFrame.")

    docs = []
    cols = list(df.columns)

    for row in df.itertuples(index=False, name=None):
        # Dynamically get the page content using the column name
        page_content_index = cols.index(page_content_column)
        page_content = row[page_content_index]

        # Construct metadata dictionary from the rest of the columns
        metadata = {col: row[cols.index(col)] for col in cols if col != page_content_column}

        # Create Document object and append to docs list
        docs.append(Document(page_content=page_content, metadata=metadata))

    return docs

docs = generate_db_docs(df, 'Description', 100)

# %%
from langchain.chains.query_constructor.base import AttributeInfo

metadata_field_info = [
    AttributeInfo(
        name="Visit ID",
        description="Unique ID for patient visting a medical center.",
        type="string",
    ),
    AttributeInfo(
        name="Visit Date",
        description="The date the visit to the medical center took place. Format: YYYYMMDD.",
        type="integer",
    ),
    AttributeInfo(
        name="Patient ID",
        description="The ID corresponding to a patient. A patient might visit multiple times, therefore the ID is not unique.",
        type="string",
    ),
    AttributeInfo(
        name="Diagnosis Category", 
        description="Category for medical diagnosis.", 
        type="string"
    ),
    AttributeInfo(
        name="Diagnosis Sub Category", 
        description="Sub category for medical diagnosis.", 
        type="string"
    ),
    AttributeInfo(
        name="Treatment Category", 
        description="Category for medical treatment based on diganosis.", 
        type="string"
    ),
    AttributeInfo(
        name="Treatment Sub Category", 
        description="Sub category for medical treatment based on diganosis.", 
        type="string"
    ),
    AttributeInfo(
        name="New Patient", 
        description="A flag indicating if it is the first time a patient is visiting the medical center. 'True' if it is the first time, 'False' if not.", 
        type="boolean"
    ),
    AttributeInfo(
        name="Consulting Physician", 
        description="The name of the consulting physician. Availbale options: 'Dr. Jerry Daniels', 'Dr. Michelle Lamb', 'Dr. James Barber', 'Dr. Shelly Hunt', 'Dr. Alexandria Gaines', 'Dr. Eddie Young'.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Name", 
        description="The name of the patient seeking medical assistance.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Gender", 
        description="The gender of the patient seeking medical assistance. Available options: 'Female', 'Male', 'Other'.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Age", 
        description="The age of the patient seeking medical assistance.", 
        type="integer"
    ),
    AttributeInfo(
        name="Patient Age Range", 
        description="The age range of the patient seeking medical assistance. Available options: '0-10', '10-20', '21-30', '31-40', '41-50', '51-64', '65+'.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Blood Type", 
        description="The blood type of the patient seeking medical assistance. Available options: 'O-', 'O+', 'AB+', 'A+', 'B+', 'A-', 'B-', 'AB-'.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Insurance Number", 
        description="The insurance number of the patient seeking medical assistance.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Phone", 
        description="The moblie phone number of the patient seeking medical assistance.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Address", 
        description="The address of the patient seeking medical assistance.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Occupation", 
        description="The occupation of the patient seeking medical assistance.", 
        type="string"
    ),
    AttributeInfo(
        name="Patient Emergency Contact", 
        description="The emergency contact of the patient seeking medical assistance. The contact includes a name and an address of the emergency contact.", 
        type="string"
    ),
    AttributeInfo(
        name="Intended Purposes", 
        description="A list of intended access purposes for the data generated at the visit to the medical center. The list can contain a set of the following options: 'Care', 'Research', 'Insurance', 'Support', 'Public', 'Trial', 'Product', 'Marketing'.", 
        type="list[string]"
    ),
]

# %%
import os

persist_directory = "./chroma_medical_db"

# Check if the persistence directory exists
if not os.path.exists(persist_directory):
    # If not, create using docs
    vectorstore = Chroma.from_documents(docs, OpenAIEmbeddings(), persist_directory=persist_directory)
    print('Creating vectorstore...')
else:
    # If the directory exists, initialize Chroma to use the existing data
    vectorstore = Chroma(persist_directory=persist_directory, embedding_function=OpenAIEmbeddings())
    print('Using existing vectorstore...')
# Out:
# Creating vectorstore...

# %%
from langchain.retrievers.self_query.base import SelfQueryRetriever
from langchain_openai import ChatOpenAI

document_content_description = "A summary of of a visit at a medical center for the docters perspective. The text includes symptoms dignosis and proposed treatment."
llm = ChatOpenAI(temperature=0)
retriever = SelfQueryRetriever.from_llm(
    llm,
    vectorstore,
    document_content_description,
    metadata_field_info,
    verbose=True,
    #return_intermediate_steps=True,
    #enable_limit=True,
)

# %%
response = retriever.invoke("Get me visits with diganosis of cancer.")
response
# Out:
# [Document(page_content='The patient presented with a suspicious mole that was later diagnosed as skin cancer. The treatment plan involved initiating chemotherapy to target and eradicate the cancerous cells. The patient was informed about the potential side effects of chemotherapy and the importance of adhering to the treatment schedule for optimal outcomes. Follow-up appointments were scheduled to monitor the response to the chemotherapy and adjust the treatment plan as needed.', metadata={'Consulting Physician': 'Dr. Alexandria Gaines', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Skin Cancer', 'Intended Purposes': "['Care', 'Insurance', 'Support', 'Public', 'Trial']", 'New Patient': True, 'Patient Address': 'Oestrovskyallee 2\n51854 Hildburghausen', 'Patient Age': 59, 'Patient Age Range': '51-64', 'Patient Blood Type': 'O+', 'Patient Emergency Contact': 'Barbara Thompson, 017647870088.', 'Patient Gender': 'Male', 'Patient ID': 'PGD755392', 'Patient Insurance Number': 'V542258607', 'Patient Name': 'Lisa Williams', 'Patient Occupation': 'Designer, multimedia', 'Patient Phone': '015320722099', 'Treatment Category': 'Cancer Treatment', 'Treatment Sub Category': 'Chemotherapy', 'Visit Date': 20170103, 'Visit ID': 'VZA334395'}),
#  Document(page_content='The patient presented with a diagnosis of skin cancer, specifically melanoma. They were started on a course of chemotherapy as part of their cancer treatment plan. The treatment aims to target and destroy the cancer cells, slowing down the progression of the disease. Common side effects of chemotherapy may include nausea, fatigue, hair loss, and increased risk of infections. Regular monitoring and supportive care will be provided to help manage any adverse effects of the treatment.', metadata={'Consulting Physician': 'Dr. Alexandria Gaines', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Skin Cancer', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Public', 'Product']", 'New Patient': True, 'Patient Address': 'Ernstallee 6/2\n28818 Dessau', 'Patient Age': 80, 'Patient Age Range': '65+', 'Patient Blood Type': 'O-', 'Patient Emergency Contact': 'Sherry Henry, 017058661610.', 'Patient Gender': 'Male', 'Patient ID': 'PLC475390', 'Patient Insurance Number': 'M978967243', 'Patient Name': 'Gabriela Mitchell', 'Patient Occupation': 'Photographer', 'Patient Phone': '016299135637', 'Treatment Category': 'Cancer Treatment', 'Treatment Sub Category': 'Chemotherapy', 'Visit Date': 20170107, 'Visit ID': 'VFX026310'}),
#  Document(page_content='The patient presented with a diagnosis of breast cancer. Upon review, it was determined that the most appropriate course of treatment would be chemotherapy. The treatment plan was discussed with the patient, outlining the potential side effects and expected outcomes. The patient has been scheduled to begin chemotherapy sessions as part of their cancer treatment regimen.', metadata={'Consulting Physician': 'Dr. James Barber', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Breast Cancer', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Public']", 'New Patient': True, 'Patient Address': 'Irmela-Bolnbach-Allee 32\n13625 Forst', 'Patient Age': 61, 'Patient Age Range': '51-64', 'Patient Blood Type': 'AB+', 'Patient Emergency Contact': 'Ashley Dixon, 016914396184.', 'Patient Gender': 'Female', 'Patient ID': 'PZO153317', 'Patient Insurance Number': 'W781967666', 'Patient Name': 'Melissa Howard', 'Patient Occupation': 'Scientist, clinical (histocompatibility and immunogenetics)', 'Patient Phone': '016005628908', 'Treatment Category': 'Cancer Treatment', 'Treatment Sub Category': 'Chemotherapy', 'Visit Date': 20170103, 'Visit ID': 'VKH924729'}),
#  Document(page_content='The patient presented with a diagnosis of lung cancer. They were started on a treatment plan involving radiation oncology to target and shrink the tumor in the lungs. The goal of the treatment is to destroy cancer cells and prevent further spread of the disease. The patient will undergo a series of radiation therapy sessions to specifically target the affected area and improve their prognosis. Regular monitoring and follow-up appointments will be scheduled to track the progress of the treatment.', metadata={'Consulting Physician': 'Dr. Shelly Hunt', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Lung Cancer', 'Intended Purposes': "['Care', 'Insurance', 'Support', 'Public', 'Trial', 'Product']", 'New Patient': True, 'Patient Address': 'Christiana-Schuster-Straße 428\n68927 Sebnitz', 'Patient Age': 54, 'Patient Age Range': '51-64', 'Patient Blood Type': 'B-', 'Patient Emergency Contact': 'Rachel Vargas, 015833040069.', 'Patient Gender': 'Male', 'Patient ID': 'PSQ736839', 'Patient Insurance Number': 'I968068732', 'Patient Name': 'Zachary Jones', 'Patient Occupation': 'Historic buildings inspector/conservation officer', 'Patient Phone': '015474820179', 'Treatment Category': 'Cancer Treatment', 'Treatment Sub Category': 'Radiation Oncology', 'Visit Date': 20170107, 'Visit ID': 'VYS949695'})]

# %%
response = retriever.invoke("Get me patients for that allow data access for research.")
response
# Out:
# [Document(page_content='The patient has been diagnosed with breast cancer. They are currently undergoing investigational treatment as part of their cancer treatment plan. The goal is to explore new and innovative approaches to managing their condition and improve their chances of successful outcomes. Close monitoring and regular assessments will be conducted to track the effectiveness of this investigational treatment.', metadata={'Consulting Physician': 'Dr. James Barber', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Breast Cancer', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Product']", 'New Patient': True, 'Patient Address': 'Henny-Bohlander-Gasse 536\n17817 Hagenow', 'Patient Age': 54, 'Patient Age Range': '51-64', 'Patient Blood Type': 'AB+', 'Patient Emergency Contact': 'Michelle Rivera, 015169080560.', 'Patient Gender': 'Female', 'Patient ID': 'PDM236997', 'Patient Insurance Number': 'P146996041', 'Patient Name': 'Rhonda Garcia', 'Patient Occupation': 'Development worker, international aid', 'Patient Phone': '017719171267', 'Treatment Category': 'Cancer Treatment', 'Treatment Sub Category': 'Investigational Treatment', 'Visit Date': 20170107, 'Visit ID': 'VDW581539'}),
#  Document(page_content="The patient presented with a diagnosis of breast cancer. After discussing the various treatment options available, we decided to enroll the patient in an investigational treatment trial for their cancer. This treatment approach aims to explore new and innovative ways to target and combat breast cancer cells. The patient will be closely monitored throughout the trial to assess the treatment's effectiveness and any potential side effects. We are hopeful that this investigational treatment will provide promising results in managing the patient's breast cancer.", metadata={'Consulting Physician': 'Dr. Michelle Lamb', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Breast Cancer', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Public']", 'New Patient': True, 'Patient Address': 'Irmhild-Wulf-Straße 5/5\n34337 Bernburg', 'Patient Age': 46, 'Patient Age Range': '41-50', 'Patient Blood Type': 'AB+', 'Patient Emergency Contact': 'Dustin Johnson, 017121672817.', 'Patient Gender': 'Female', 'Patient ID': 'PTY324114', 'Patient Insurance Number': 'Private', 'Patient Name': 'Wendy Anderson', 'Patient Occupation': 'Careers adviser', 'Patient Phone': '015063353778', 'Treatment Category': 'Cancer Treatment', 'Treatment Sub Category': 'Investigational Treatment', 'Visit Date': 20170107, 'Visit ID': 'VJG054580'}),
#  Document(page_content='Today I saw a patient with a suspected diagnosis of colon cancer. To further investigate, I ordered lab work as part of the diagnostic imaging, screening, and testing process. The lab work will help provide valuable information to confirm the diagnosis and determine the best course of treatment moving forward.', metadata={'Consulting Physician': 'Dr. James Barber', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Colon Cancer', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Public', 'Trial']", 'New Patient': True, 'Patient Address': 'Ullmannweg 26\n82008 Dachau', 'Patient Age': 51, 'Patient Age Range': '51-64', 'Patient Blood Type': 'A+', 'Patient Emergency Contact': 'Stephanie Boyd, 015784302931.', 'Patient Gender': 'Male', 'Patient ID': 'PJZ848816', 'Patient Insurance Number': 'U225485795', 'Patient Name': 'Hannah Kelley', 'Patient Occupation': 'Brewing technologist', 'Patient Phone': '017263811068', 'Treatment Category': 'Diagnostic Imaging, Screening and Testing', 'Treatment Sub Category': 'Lab Work', 'Visit Date': 20170106, 'Visit ID': 'VEC573897'}),
#  Document(page_content='I performed an ultrasound on the pregnant patient to monitor the growth and development of the fetus. The imaging helped assess the health of the pregnancy and ensure everything is progressing as expected.', metadata={'Consulting Physician': 'Dr. Jerry Daniels', 'Diagnosis Category': 'OB-Gyn/ Pregnancy', 'Diagnosis Sub Category': 'Pregnancy', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Trial']", 'New Patient': True, 'Patient Address': 'Gerlind-Fischer-Gasse 081\n69061 Norden', 'Patient Age': 32, 'Patient Age Range': '31-40', 'Patient Blood Type': 'B+', 'Patient Emergency Contact': 'Danielle Frank, 017348515766.', 'Patient Gender': 'Female', 'Patient ID': 'PSX651090', 'Patient Insurance Number': 'D441944945', 'Patient Name': 'Taylor Jennings', 'Patient Occupation': 'Armed forces operational officer', 'Patient Phone': '016942777937', 'Treatment Category': 'Diagnostic Imaging, Screening and Testing', 'Treatment Sub Category': 'Ultrasound', 'Visit Date': 20170107, 'Visit ID': 'VQL009776'})]

# %%
response = retriever.invoke("Get me patients with blood type A-")
response
# Out:
# [Document(page_content="The patient presented with elevated blood pressure readings consistent with a diagnosis of hypertension. As part of the treatment plan, I discussed the option of prescribing formulary versus non-formulary medications to help manage their condition. We reviewed the benefits and potential side effects of each type of medication to determine the most suitable choice for the patient's specific needs.", metadata={'Consulting Physician': 'Dr. Jerry Daniels', 'Diagnosis Category': 'Cardiac/Circulatory', 'Diagnosis Sub Category': 'Hypertension', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Public', 'Trial']", 'New Patient': True, 'Patient Address': 'Minna-Klotz-Gasse 1\n55843 Hannoversch Münden', 'Patient Age': 61, 'Patient Age Range': '51-64', 'Patient Blood Type': 'A-', 'Patient Emergency Contact': 'Paul Vincent, 017740391054.', 'Patient Gender': 'Male', 'Patient ID': 'PVW942378', 'Patient Insurance Number': 'Y945492970', 'Patient Name': 'Larry Frazier', 'Patient Occupation': 'Engineer, communications', 'Patient Phone': '017779937605', 'Treatment Category': 'Pharmacy/Prescription Drugs', 'Treatment Sub Category': 'Formulary versus Non-Formulary', 'Visit Date': 20170108, 'Visit ID': 'VRD010133'}),
#  Document(page_content="The patient presented with symptoms of jaundice, fatigue, and abdominal pain, indicative of Hepatitis. After confirming the diagnosis, I prescribed antiviral medication to help manage the viral infection and prevent further complications. I explained the importance of strict adherence to the medication regimen and scheduled follow-up appointments to monitor the patient's progress.", metadata={'Consulting Physician': 'Dr. Shelly Hunt', 'Diagnosis Category': 'Infectious', 'Diagnosis Sub Category': 'Hepatitis', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Public', 'Trial', 'Product']", 'New Patient': True, 'Patient Address': 'Kabusplatz 62\n68020 Hohenmölsen', 'Patient Age': 57, 'Patient Age Range': '51-64', 'Patient Blood Type': 'A-', 'Patient Emergency Contact': 'Alison Adkins, 015697595509.', 'Patient Gender': 'Male', 'Patient ID': 'PSG410723', 'Patient Insurance Number': 'X383290854', 'Patient Name': 'Andrea Johnson', 'Patient Occupation': 'Public affairs consultant', 'Patient Phone': '017105844986', 'Treatment Category': 'Pharmacy/Prescription Drugs', 'Treatment Sub Category': 'Anti-virals', 'Visit Date': 20170107, 'Visit ID': 'VZA879696'}),
#  Document(page_content='The patient presented with symptoms indicative of Hepatitis, such as jaundice, fatigue, and abdominal pain. After confirming the diagnosis, I prescribed antiviral medication to target the underlying viral infection and prevent further liver damage. I advised the patient on the importance of rest, proper nutrition, and avoiding alcohol during the treatment period. Follow-up appointments were scheduled to monitor progress and adjust the treatment plan as needed.', metadata={'Consulting Physician': 'Dr. Jerry Daniels', 'Diagnosis Category': 'Infectious', 'Diagnosis Sub Category': 'Hepatitis', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Trial']", 'New Patient': True, 'Patient Address': 'Kirstin-Sager-Straße 252\n08783 Monschau', 'Patient Age': 61, 'Patient Age Range': '51-64', 'Patient Blood Type': 'A-', 'Patient Emergency Contact': 'Sarah Greene, 016845686437.', 'Patient Gender': 'Female', 'Patient ID': 'POY777417', 'Patient Insurance Number': 'Private', 'Patient Name': 'Jesse Cooper', 'Patient Occupation': 'Lobbyist', 'Patient Phone': '015270464446', 'Treatment Category': 'Pharmacy/Prescription Drugs', 'Treatment Sub Category': 'Anti-virals', 'Visit Date': 20170104, 'Visit ID': 'VEO439666'}),
#  Document(page_content='The patient presented with severe back pain, radiating down one or both legs, along with numbness and tingling. After a thorough evaluation, including imaging studies, the diagnosis of a vertebral disc problem was confirmed. Due to the urgency of the situation, the patient was immediately taken to the emergency room for further evaluation and management.', metadata={'Consulting Physician': 'Dr. James Barber', 'Diagnosis Category': 'Orthopedic/ Musculoskeletal', 'Diagnosis Sub Category': 'Vertebral Disc Problem', 'Intended Purposes': "['Care', 'Insurance', 'Support']", 'New Patient': True, 'Patient Address': 'Gudegasse 8\n90001 Weimar', 'Patient Age': 33, 'Patient Age Range': '31-40', 'Patient Blood Type': 'A-', 'Patient Emergency Contact': 'Jack Wu, 016763338246.', 'Patient Gender': 'Male', 'Patient ID': 'PSL169799', 'Patient Insurance Number': 'V254017452', 'Patient Name': 'Dale Daniels', 'Patient Occupation': 'Contracting civil engineer', 'Patient Phone': '017040564919', 'Treatment Category': 'Emergency/Urgent Care', 'Treatment Sub Category': 'Emergency Room', 'Visit Date': 20170102, 'Visit ID': 'VWH998027'})]

# %%
response = retriever.invoke("Get me patients that struggle with blood pressure.")
response
# Out:
# [Document(page_content="The patient presented with elevated blood pressure readings consistent with a diagnosis of hypertension. As part of the treatment plan, I discussed the option of prescribing formulary versus non-formulary medications to help manage their condition. We reviewed the benefits and potential side effects of each type of medication to determine the most suitable choice for the patient's specific needs.", metadata={'Consulting Physician': 'Dr. Jerry Daniels', 'Diagnosis Category': 'Cardiac/Circulatory', 'Diagnosis Sub Category': 'Hypertension', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Public', 'Trial']", 'New Patient': True, 'Patient Address': 'Minna-Klotz-Gasse 1\n55843 Hannoversch Münden', 'Patient Age': 61, 'Patient Age Range': '51-64', 'Patient Blood Type': 'A-', 'Patient Emergency Contact': 'Paul Vincent, 017740391054.', 'Patient Gender': 'Male', 'Patient ID': 'PVW942378', 'Patient Insurance Number': 'Y945492970', 'Patient Name': 'Larry Frazier', 'Patient Occupation': 'Engineer, communications', 'Patient Phone': '017779937605', 'Treatment Category': 'Pharmacy/Prescription Drugs', 'Treatment Sub Category': 'Formulary versus Non-Formulary', 'Visit Date': 20170108, 'Visit ID': 'VRD010133'}),
#  Document(page_content='The patient presented with morbid obesity and was found to have hypertension during the evaluation. Due to the severity of the obesity, a general surgery consultation was requested to discuss potential surgical interventions for weight loss. The patient will undergo further assessments to determine the most suitable surgical approach to help manage the obesity and potentially improve the hypertension in the long term.', metadata={'Consulting Physician': 'Dr. Eddie Young', 'Diagnosis Category': 'Morbid Obesity', 'Diagnosis Sub Category': 'Hypertension', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Public']", 'New Patient': True, 'Patient Address': 'Walentina-Hörle-Gasse 9/8\n76338 Badibling', 'Patient Age': 45, 'Patient Age Range': '41-50', 'Patient Blood Type': 'AB-', 'Patient Emergency Contact': 'Mr. Christian Meyer, 017908913420.', 'Patient Gender': 'Male', 'Patient ID': 'PFT099340', 'Patient Insurance Number': 'V131811596', 'Patient Name': 'Deanna Sanchez', 'Patient Occupation': 'Leisure centre manager', 'Patient Phone': '015421975485', 'Treatment Category': 'General Surgery', 'Visit Date': 20170104, 'Visit ID': 'VGG717904'}),
#  Document(page_content='The patient presented with severe hypertension secondary to morbid obesity. After discussing the risks and benefits, we decided that bariatric surgery would be the most effective treatment option. The patient was scheduled for a general surgery procedure aimed at reducing their weight and improving their overall health. Proper post-operative care and lifestyle modifications were also discussed to ensure the best possible outcome for the patient.', metadata={'Consulting Physician': 'Dr. James Barber', 'Diagnosis Category': 'Morbid Obesity', 'Diagnosis Sub Category': 'Hypertension', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Public']", 'New Patient': True, 'Patient Address': 'Heidrun-Bachmann-Ring 0/9\n81280 Rastatt', 'Patient Age': 42, 'Patient Age Range': '41-50', 'Patient Blood Type': 'AB-', 'Patient Emergency Contact': 'Gregory Erickson, 017197902562.', 'Patient Gender': 'Female', 'Patient ID': 'PAE552573', 'Patient Insurance Number': 'Private', 'Patient Name': 'Nicholas Ryan', 'Patient Occupation': 'Geographical information systems officer', 'Patient Phone': '015839275476', 'Treatment Category': 'General Surgery', 'Treatment Sub Category': 'Bariatric Other', 'Visit Date': 20170107, 'Visit ID': 'VGG074517'}),
#  Document(page_content='The patient was diagnosed with diabetes and prescribed a medication typically used for a different condition in an off-label manner to help manage their blood sugar levels.', metadata={'Consulting Physician': 'Dr. Alexandria Gaines', 'Diagnosis Category': 'Endocrine/ Metabolic', 'Diagnosis Sub Category': 'Diabetes', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Public', 'Trial']", 'New Patient': True, 'Patient Address': 'Wähnerstraße 9\n99501 Bad Mergentheim', 'Patient Age': 55, 'Patient Age Range': '51-64', 'Patient Blood Type': 'A+', 'Patient Emergency Contact': 'Jeffery Mendoza, 017418231951.', 'Patient Gender': 'Male', 'Patient ID': 'PXU529928', 'Patient Insurance Number': 'B638952896', 'Patient Name': 'Shari Patterson', 'Patient Occupation': 'Risk manager', 'Patient Phone': '016697841069', 'Treatment Category': 'Pharmacy/Prescription Drugs', 'Treatment Sub Category': 'Non-FDA Approved Use', 'Visit Date': 20170108, 'Visit ID': 'VCD049551'})]

# %%
from langchain.chains.query_constructor.base import (
    StructuredQueryOutputParser,
    get_query_constructor_prompt,
)

prompt = get_query_constructor_prompt(
    document_content_description,
    metadata_field_info,
)
output_parser = StructuredQueryOutputParser.from_components()
query_constructor = prompt | llm | output_parser

# %%
from langchain.retrievers.self_query.chroma import ChromaTranslator

retriever = SelfQueryRetriever(
    query_constructor=query_constructor,
    vectorstore=vectorstore,
    structured_query_translator=ChromaTranslator(),
)

# %%
print(query_constructor.invoke(
        {
            "query": "Get all patients with cancer."
        }
    )
)

print(retriever.invoke(
        "Get all patients with cancer."
    )
)
# Out:
# query='cancer' filter=Comparison(comparator=<Comparator.EQ: 'eq'>, attribute='Diagnosis Category', value='Cancer') limit=None
# [Document(page_content='The patient presented with a suspicious mole that was later diagnosed as skin cancer. The treatment plan involved initiating chemotherapy to target and eradicate the cancerous cells. The patient was informed about the potential side effects of chemotherapy and the importance of adhering to the treatment schedule for optimal outcomes. Follow-up appointments were scheduled to monitor the response to the chemotherapy and adjust the treatment plan as needed.', metadata={'Consulting Physician': 'Dr. Alexandria Gaines', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Skin Cancer', 'Intended Purposes': "['Care', 'Insurance', 'Support', 'Public', 'Trial']", 'New Patient': True, 'Patient Address': 'Oestrovskyallee 2\n51854 Hildburghausen', 'Patient Age': 59, 'Patient Age Range': '51-64', 'Patient Blood Type': 'O+', 'Patient Emergency Contact': 'Barbara Thompson, 017647870088.', 'Patient Gender': 'Male', 'Patient ID': 'PGD755392', 'Patient Insurance Number': 'V542258607', 'Patient Name': 'Lisa Williams', 'Patient Occupation': 'Designer, multimedia', 'Patient Phone': '015320722099', 'Treatment Category': 'Cancer Treatment', 'Treatment Sub Category': 'Chemotherapy', 'Visit Date': 20170103, 'Visit ID': 'VZA334395'}), Document(page_content='The patient presented with a diagnosis of skin cancer, specifically melanoma. They were started on a course of chemotherapy as part of their cancer treatment plan. The treatment aims to target and destroy the cancer cells, slowing down the progression of the disease. Common side effects of chemotherapy may include nausea, fatigue, hair loss, and increased risk of infections. Regular monitoring and supportive care will be provided to help manage any adverse effects of the treatment.', metadata={'Consulting Physician': 'Dr. Alexandria Gaines', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Skin Cancer', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Public', 'Product']", 'New Patient': True, 'Patient Address': 'Ernstallee 6/2\n28818 Dessau', 'Patient Age': 80, 'Patient Age Range': '65+', 'Patient Blood Type': 'O-', 'Patient Emergency Contact': 'Sherry Henry, 017058661610.', 'Patient Gender': 'Male', 'Patient ID': 'PLC475390', 'Patient Insurance Number': 'M978967243', 'Patient Name': 'Gabriela Mitchell', 'Patient Occupation': 'Photographer', 'Patient Phone': '016299135637', 'Treatment Category': 'Cancer Treatment', 'Treatment Sub Category': 'Chemotherapy', 'Visit Date': 20170107, 'Visit ID': 'VFX026310'}), Document(page_content='The patient presented with a diagnosis of breast cancer. Upon review, it was determined that the most appropriate course of treatment would be chemotherapy. The treatment plan was discussed with the patient, outlining the potential side effects and expected outcomes. The patient has been scheduled to begin chemotherapy sessions as part of their cancer treatment regimen.', metadata={'Consulting Physician': 'Dr. James Barber', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Breast Cancer', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Public']", 'New Patient': True, 'Patient Address': 'Irmela-Bolnbach-Allee 32\n13625 Forst', 'Patient Age': 61, 'Patient Age Range': '51-64', 'Patient Blood Type': 'AB+', 'Patient Emergency Contact': 'Ashley Dixon, 016914396184.', 'Patient Gender': 'Female', 'Patient ID': 'PZO153317', 'Patient Insurance Number': 'W781967666', 'Patient Name': 'Melissa Howard', 'Patient Occupation': 'Scientist, clinical (histocompatibility and immunogenetics)', 'Patient Phone': '016005628908', 'Treatment Category': 'Cancer Treatment', 'Treatment Sub Category': 'Chemotherapy', 'Visit Date': 20170103, 'Visit ID': 'VKH924729'}), Document(page_content='The patient presented with a diagnosis of lung cancer. They were started on a treatment plan involving radiation oncology to target and shrink the tumor in the lungs. The goal of the treatment is to destroy cancer cells and preven ...

# %%
retriever.invoke(
    "Get all patients with cancer."
)
# Out:
# [Document(page_content='The patient presented with a suspicious mole that was later diagnosed as skin cancer. The treatment plan involved initiating chemotherapy to target and eradicate the cancerous cells. The patient was informed about the potential side effects of chemotherapy and the importance of adhering to the treatment schedule for optimal outcomes. Follow-up appointments were scheduled to monitor the response to the chemotherapy and adjust the treatment plan as needed.', metadata={'Consulting Physician': 'Dr. Alexandria Gaines', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Skin Cancer', 'Intended Purposes': "['Care', 'Insurance', 'Support', 'Public', 'Trial']", 'New Patient': True, 'Patient Address': 'Oestrovskyallee 2\n51854 Hildburghausen', 'Patient Age': 59, 'Patient Age Range': '51-64', 'Patient Blood Type': 'O+', 'Patient Emergency Contact': 'Barbara Thompson, 017647870088.', 'Patient Gender': 'Male', 'Patient ID': 'PGD755392', 'Patient Insurance Number': 'V542258607', 'Patient Name': 'Lisa Williams', 'Patient Occupation': 'Designer, multimedia', 'Patient Phone': '015320722099', 'Treatment Category': 'Cancer Treatment', 'Treatment Sub Category': 'Chemotherapy', 'Visit Date': 20170103, 'Visit ID': 'VZA334395'}),
#  Document(page_content='The patient presented with a diagnosis of skin cancer, specifically melanoma. They were started on a course of chemotherapy as part of their cancer treatment plan. The treatment aims to target and destroy the cancer cells, slowing down the progression of the disease. Common side effects of chemotherapy may include nausea, fatigue, hair loss, and increased risk of infections. Regular monitoring and supportive care will be provided to help manage any adverse effects of the treatment.', metadata={'Consulting Physician': 'Dr. Alexandria Gaines', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Skin Cancer', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Public', 'Product']", 'New Patient': True, 'Patient Address': 'Ernstallee 6/2\n28818 Dessau', 'Patient Age': 80, 'Patient Age Range': '65+', 'Patient Blood Type': 'O-', 'Patient Emergency Contact': 'Sherry Henry, 017058661610.', 'Patient Gender': 'Male', 'Patient ID': 'PLC475390', 'Patient Insurance Number': 'M978967243', 'Patient Name': 'Gabriela Mitchell', 'Patient Occupation': 'Photographer', 'Patient Phone': '016299135637', 'Treatment Category': 'Cancer Treatment', 'Treatment Sub Category': 'Chemotherapy', 'Visit Date': 20170107, 'Visit ID': 'VFX026310'}),
#  Document(page_content='The patient presented with a diagnosis of breast cancer. Upon review, it was determined that the most appropriate course of treatment would be chemotherapy. The treatment plan was discussed with the patient, outlining the potential side effects and expected outcomes. The patient has been scheduled to begin chemotherapy sessions as part of their cancer treatment regimen.', metadata={'Consulting Physician': 'Dr. James Barber', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Breast Cancer', 'Intended Purposes': "['Care', 'Research', 'Insurance', 'Support', 'Public']", 'New Patient': True, 'Patient Address': 'Irmela-Bolnbach-Allee 32\n13625 Forst', 'Patient Age': 61, 'Patient Age Range': '51-64', 'Patient Blood Type': 'AB+', 'Patient Emergency Contact': 'Ashley Dixon, 016914396184.', 'Patient Gender': 'Female', 'Patient ID': 'PZO153317', 'Patient Insurance Number': 'W781967666', 'Patient Name': 'Melissa Howard', 'Patient Occupation': 'Scientist, clinical (histocompatibility and immunogenetics)', 'Patient Phone': '016005628908', 'Treatment Category': 'Cancer Treatment', 'Treatment Sub Category': 'Chemotherapy', 'Visit Date': 20170103, 'Visit ID': 'VKH924729'}),
#  Document(page_content='The patient presented with a diagnosis of lung cancer. They were started on a treatment plan involving radiation oncology to target and shrink the tumor in the lungs. The goal of the treatment is to destroy cancer cells and prevent further spread of the disease. The patient will undergo a series of radiation therapy sessions to specifically target the affected area and improve their prognosis. Regular monitoring and follow-up appointments will be scheduled to track the progress of the treatment.', metadata={'Consulting Physician': 'Dr. Shelly Hunt', 'Diagnosis Category': 'Cancer', 'Diagnosis Sub Category': 'Lung Cancer', 'Intended Purposes': "['Care', 'Insurance', 'Support', 'Public', 'Trial', 'Product']", 'New Patient': True, 'Patient Address': 'Christiana-Schuster-Straße 428\n68927 Sebnitz', 'Patient Age': 54, 'Patient Age Range': '51-64', 'Patient Blood Type': 'B-', 'Patient Emergency Contact': 'Rachel Vargas, 015833040069.', 'Patient Gender': 'Male', 'Patient ID': 'PSQ736839', 'Patient Insurance Number': 'I968068732', 'Patient Name': 'Zachary Jones', 'Patient Occupation': 'Historic buildings inspector/conservation officer', 'Patient Phone': '015474820179', 'Treatment Category': 'Cancer Treatment', 'Treatment Sub Category': 'Radiation Oncology', 'Visit Date': 20170107, 'Visit ID': 'VYS949695'})]
